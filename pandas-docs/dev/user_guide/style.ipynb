# %% [markdown]
# # Table Visualization
#
# This section demonstrates visualization of tabular data using the [Styler][styler]
# class. For information on visualization with charting please see [Chart Visualization][viz]. This document is written as a Jupyter Notebook, and can be viewed or downloaded [here][download].
#
# ## Styler Object and Customising the Display
# Styling and output display customisation should be performed **after** the data in a DataFrame has been processed. The Styler is **not** dynamically updated if further changes to the DataFrame are made. The `DataFrame.style` attribute is a property that returns a [Styler][styler] object. It has a `_repr_html_` method defined on it so it is rendered automatically in Jupyter Notebook.
#
# The Styler, which can be used for large data but is primarily designed for small data, currently has the ability to output to these formats:
#
#   - HTML
#   - LaTeX
#   - String (and CSV by extension)
#   - Excel
#   - (JSON is not currently available)
#
# The first three of these have display customisation methods designed to format and customise the output. These include:
#
#   - Formatting values, the index and columns headers, using [.format()][formatfunc] and [.format_index()][formatfuncindex],
#   - Renaming the index or column header labels, using [.relabel_index()][relabelfunc]
#   - Hiding certain columns, the index and/or column headers, or index names, using [.hide()][hidefunc]
#   - Concatenating similar DataFrames, using [.concat()][concatfunc]
#
# [styler]: ../reference/api/pandas.io.formats.style.Styler.rst
# [viz]: visualization.rst
# [download]: https://nbviewer.org/github/pandas-dev/pandas/blob/main/doc/source/user_guide/style.ipynb
# [format]: https://docs.python.org/3/library/string.html#format-specification-mini-language
# [formatfunc]: ../reference/api/pandas.io.formats.style.Styler.format.rst
# [formatfuncindex]: ../reference/api/pandas.io.formats.style.Styler.format_index.rst
# [relabelfunc]: ../reference/api/pandas.io.formats.style.Styler.relabel_index.rst
# [hidefunc]: ../reference/api/pandas.io.formats.style.Styler.hide.rst
# [concatfunc]: ../reference/api/pandas.io.formats.style.Styler.concat.rst

# %% [markdown]
# ## Formatting the Display
#
# ### Formatting Values
#
# The [Styler][styler] distinguishes the *display* value from the *actual* value, in both data values and index or columns headers. To control the display value, the text is printed in each cell as a string, and we can use the [.format()][formatfunc] and [.format_index()][formatfuncindex] methods to manipulate this according to a [format spec string][format] or a callable that takes a single value and returns a string. It is possible to define this for the whole table, or index, or for individual columns, or MultiIndex levels. We can also overwrite index names.
#
# Additionally, the format function has a **precision** argument to specifically help format floats, as well as **decimal** and **thousands** separators to support other locales, an **na_rep** argument to display missing data, and an **escape** and **hyperlinks** arguments to help displaying safe-HTML or safe-LaTeX. The default formatter is configured to adopt pandas' global options such as `styler.format.precision` option, controllable using `with pd.option_context('format.precision', 2):`
#
# [styler]: ../reference/api/pandas.io.formats.style.Styler.rst
# [format]: https://docs.python.org/3/library/string.html#format-specification-mini-language
# [formatfunc]: ../reference/api/pandas.io.formats.style.Styler.format.rst
# [formatfuncindex]: ../reference/api/pandas.io.formats.style.Styler.format_index.rst
# [relabelfunc]: ../reference/api/pandas.io.formats.style.Styler.relabel_index.rst

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {"strings": ["Adam", "Mike"], "ints": [1, 3], "floats": [1.123, 1000.23]}
)
df.style.format(precision=3, thousands=".", decimal=",").format_index(
    str.upper, axis=1
).relabel_index(["row 1", "row 2"], axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6462e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6462e_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_6462e_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_6462e_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6462e_level0_row0" class="row_heading level0 row0" >row 1</th>
#       <td id="T_6462e_row0_col0" class="data row0 col0" >Adam</td>
#       <td id="T_6462e_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_6462e_row0_col2" class="data row0 col2" >1,123</td>
#     </tr>
#     <tr>
#       <th id="T_6462e_level0_row1" class="row_heading level0 row1" >row 2</th>
#       <td id="T_6462e_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_6462e_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_6462e_row1_col2" class="data row1 col2" >1.000,230</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Using Styler to manipulate the display is a useful feature because maintaining the indexing and data values for other purposes gives greater control. You do not have to overwrite your DataFrame to display it how you like. Here is a more comprehensive example of using the formatting functions whilst still relying on the underlying data for indexing and calculations.

# %%
weather_df = pd.DataFrame(
    np.random.default_rng().random((10, 2)) * 5,
    index=pd.date_range(start="2021-01-01", periods=10),
    columns=["Tokyo", "Beijing"],
)


def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"


def make_pretty(styler):
    styler.set_caption("Weather Conditions")
    styler.format(rain_condition)
    styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    return styler


weather_df
# Out:
#                Tokyo   Beijing
# 2021-01-01  2.802182  2.130941
# 2021-01-02  0.421010  1.954825
# 2021-01-03  0.769151  1.051861
# 2021-01-04  2.908180  0.275801
# 2021-01-05  2.745315  0.675468
# 2021-01-06  3.849863  2.847331
# 2021-01-07  3.691405  0.036258
# 2021-01-08  2.579696  3.683570
# 2021-01-09  0.218023  4.641958
# 2021-01-10  3.083245  0.227158

# %%
weather_df.loc["2021-01-04":"2021-01-08"].style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_c3655_row0_col0 {
#   background-color: #4cbac2;
#   color: #f1f1f1;
# }
# #T_c3655_row0_col1, #T_c3655_row1_col1, #T_c3655_row3_col1 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_c3655_row1_col0 {
#   background-color: #61c2bf;
#   color: #000000;
# }
# #T_c3655_row2_col0 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_c3655_row2_col1 {
#   background-color: #53bdc1;
#   color: #000000;
# }
# #T_c3655_row3_col0 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
# }
# #T_c3655_row4_col0 {
#   background-color: #75c9bd;
#   color: #000000;
# }
# #T_c3655_row4_col1 {
#   background-color: #1f7eb7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c3655">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3655_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_c3655_level0_col1" class="col_heading level0 col1" >Beijing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3655_level0_row0" class="row_heading level0 row0" >Monday</th>
#       <td id="T_c3655_row0_col0" class="data row0 col0" >Heavy Rain</td>
#       <td id="T_c3655_row0_col1" class="data row0 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_c3655_level0_row1" class="row_heading level0 row1" >Tuesday</th>
#       <td id="T_c3655_row1_col0" class="data row1 col0" >Rain</td>
#       <td id="T_c3655_row1_col1" class="data row1 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_c3655_level0_row2" class="row_heading level0 row2" >Wednesday</th>
#       <td id="T_c3655_row2_col0" class="data row2 col0" >Heavy Rain</td>
#       <td id="T_c3655_row2_col1" class="data row2 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_c3655_level0_row3" class="row_heading level0 row3" >Thursday</th>
#       <td id="T_c3655_row3_col0" class="data row3 col0" >Heavy Rain</td>
#       <td id="T_c3655_row3_col1" class="data row3 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_c3655_level0_row4" class="row_heading level0 row4" >Friday</th>
#       <td id="T_c3655_row4_col0" class="data row4 col0" >Rain</td>
#       <td id="T_c3655_row4_col1" class="data row4 col1" >Heavy Rain</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Hiding Data
#
# The index and column headers can be completely hidden, as well subselecting rows or columns that one wishes to exclude. Both these options are performed using the same methods.
#
# The index can be hidden from rendering by calling [.hide()][hideidx] without any arguments, which might be useful if your index is integer based. Similarly column headers can be hidden by calling [.hide(axis="columns")][hideidx] without any further arguments.
#
# Specific rows or columns can be hidden from rendering by calling the same [.hide()][hideidx] method and passing in a row/column label, a list-like or a slice of row/column labels to for the ``subset`` argument.
#
# Hiding does not change the integer arrangement of CSS classes, e.g. hiding the first two columns of a DataFrame means the column class indexing will still start at `col2`, since `col0` and `col1` are simply ignored.
#
# [hideidx]: ../reference/api/pandas.io.formats.style.Styler.hide.rst

# %%
df = pd.DataFrame(np.random.default_rng().standard_normal((5, 5)))
df.style.hide(subset=[0, 2, 4], axis=0).hide(subset=[0, 2, 4], axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_be410">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be410_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_be410_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be410_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be410_row1_col1" class="data row1 col1" >0.472824</td>
#       <td id="T_be410_row1_col3" class="data row1 col3" >-1.109770</td>
#     </tr>
#     <tr>
#       <th id="T_be410_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be410_row3_col1" class="data row3 col1" >-1.328191</td>
#       <td id="T_be410_row3_col3" class="data row3 col3" >0.898953</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# To invert the function to a **show** functionality it is best practice to compose a list of hidden items.

# %%
show = [0, 2, 4]
df.style.hide([row for row in df.index if row not in show], axis=0).hide(
    [col for col in df.columns if col not in show], axis=1
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b3745">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3745_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b3745_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_b3745_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3745_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3745_row0_col0" class="data row0 col0" >0.062362</td>
#       <td id="T_b3745_row0_col2" class="data row0 col2" >-0.246094</td>
#       <td id="T_b3745_row0_col4" class="data row0 col4" >-0.220595</td>
#     </tr>
#     <tr>
#       <th id="T_b3745_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3745_row2_col0" class="data row2 col0" >-0.243372</td>
#       <td id="T_b3745_row2_col2" class="data row2 col2" >-1.711557</td>
#       <td id="T_b3745_row2_col4" class="data row2 col4" >0.311215</td>
#     </tr>
#     <tr>
#       <th id="T_b3745_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3745_row4_col0" class="data row4 col0" >-0.912117</td>
#       <td id="T_b3745_row4_col2" class="data row4 col2" >-0.456306</td>
#       <td id="T_b3745_row4_col4" class="data row4 col4" >-1.515603</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Concatenating DataFrame Outputs
#
# Two or more Stylers can be concatenated together provided they share the same columns. This is very useful for showing summary statistics for a DataFrame, and is often used in combination with DataFrame.agg.
#
# Since the objects concatenated are Stylers they can independently be styled as will be shown below and their concatenation preserves those styles.

# %%
summary_styler = (
    df.agg(["sum", "mean"]).style.format(precision=3).relabel_index(["Sum", "Average"])
)
df.style.format(precision=1).concat(summary_styler)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae407">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae407_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ae407_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ae407_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_ae407_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_ae407_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae407_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae407_row0_col0" class="data row0 col0" >0.1</td>
#       <td id="T_ae407_row0_col1" class="data row0 col1" >-0.2</td>
#       <td id="T_ae407_row0_col2" class="data row0 col2" >-0.2</td>
#       <td id="T_ae407_row0_col3" class="data row0 col3" >0.4</td>
#       <td id="T_ae407_row0_col4" class="data row0 col4" >-0.2</td>
#     </tr>
#     <tr>
#       <th id="T_ae407_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae407_row1_col0" class="data row1 col0" >-0.8</td>
#       <td id="T_ae407_row1_col1" class="data row1 col1" >0.5</td>
#       <td id="T_ae407_row1_col2" class="data row1 col2" >-1.1</td>
#       <td id="T_ae407_row1_col3" class="data row1 col3" >-1.1</td>
#       <td id="T_ae407_row1_col4" class="data row1 col4" >0.9</td>
#     </tr>
#     <tr>
#       <th id="T_ae407_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae407_row2_col0" class="data row2 col0" >-0.2</td>
#       <td id="T_ae407_row2_col1" class="data row2 col1" >-0.2</td>
#       <td id="T_ae407_row2_col2" class="data row2 col2" >-1.7</td>
#       <td id="T_ae407_row2_col3" class="data row2 col3" >0.7</td>
#       <td id="T_ae407_row2_col4" class="data row2 col4" >0.3</td>
#     </tr>
#     <tr>
#       <th id="T_ae407_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ae407_row3_col0" class="data row3 col0" >2.7</td>
#       <td id="T_ae407_row3_col1" class="data row3 col1" >-1.3</td>
#       <td id="T_ae407_row3_col2" class="data row3 col2" >-0.9</td>
#       <td id="T_ae407_row3_col3" class="data row3 col3" >0.9</td>
#       <td id="T_ae407_row3_col4" class="data row3 col4" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_ae407_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ae407_row4_col0" class="data row4 col0" >-0.9</td>
#       <td id="T_ae407_row4_col1" class="data row4 col1" >0.1</td>
#       <td id="T_ae407_row4_col2" class="data row4 col2" >-0.5</td>
#       <td id="T_ae407_row4_col3" class="data row4 col3" >1.3</td>
#       <td id="T_ae407_row4_col4" class="data row4 col4" >-1.5</td>
#     </tr>
#     <tr>
#       <th id="T_ae407_level0_foot0_row0" class="foot0_row_heading level0 foot0_row0" >Sum</th>
#       <td id="T_ae407_foot0_row0_col0" class="foot0_data foot0_row0 col0" >0.836</td>
#       <td id="T_ae407_foot0_row0_col1" class="foot0_data foot0_row0 col1" >-1.218</td>
#       <td id="T_ae407_foot0_row0_col2" class="foot0_data foot0_row0 col2" >-4.423</td>
#       <td id="T_ae407_foot0_row0_col3" class="foot0_data foot0_row0 col3" >2.153</td>
#       <td id="T_ae407_foot0_row0_col4" class="foot0_data foot0_row0 col4" >-0.447</td>
#     </tr>
#     <tr>
#       <th id="T_ae407_level0_foot0_row1" class="foot0_row_heading level0 foot0_row1" >Average</th>
#       <td id="T_ae407_foot0_row1_col0" class="foot0_data foot0_row1 col0" >0.167</td>
#       <td id="T_ae407_foot0_row1_col1" class="foot0_data foot0_row1 col1" >-0.244</td>
#       <td id="T_ae407_foot0_row1_col2" class="foot0_data foot0_row1 col2" >-0.885</td>
#       <td id="T_ae407_foot0_row1_col3" class="foot0_data foot0_row1 col3" >0.431</td>
#       <td id="T_ae407_foot0_row1_col4" class="foot0_data foot0_row1 col4" >-0.089</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Styler Object and HTML
#
# The [Styler][styler] was originally constructed to support the wide array of HTML formatting options. Its HTML output creates an HTML `<table>` and leverages CSS styling language to manipulate many parameters including colors, fonts, borders, background, etc. See [here][w3schools] for more information on styling HTML tables. This allows a lot of flexibility out of the box, and even enables web developers to integrate DataFrames into their existing user interface designs.
#
# Below we demonstrate the default output, which looks very similar to the standard DataFrame HTML representation. But the HTML here has already attached some CSS classes to each cell, even if we haven't yet created any styles. We can view these by calling the  [.to_html()][tohtml] method, which returns the raw HTML as string, which is useful for further processing or adding to a file - read on in [More about CSS and HTML](#More-About-CSS-and-HTML). This section will also provide a walkthrough for how to convert this default output to represent a DataFrame output that is more communicative. For example how we can build `s`:
#
# [tohtml]: ../reference/api/pandas.io.formats.style.Styler.to_html.rst
#
# [styler]: ../reference/api/pandas.io.formats.style.Styler.rst
# [w3schools]: https://www.w3schools.com/html/html_tables.asp

# %%
idx = pd.Index(["Tumour (Positive)", "Non-Tumour (Negative)"], name="Actual Label:")
cols = pd.MultiIndex.from_product(
    [["Decision Tree", "Regression", "Random"], ["Tumour", "Non-Tumour"]],
    names=["Model:", "Predicted:"],
)
df = pd.DataFrame(
    [[38.0, 2.0, 18.0, 22.0, 21, np.nan], [19, 439, 6, 452, 226, 232]],
    index=idx,
    columns=cols,
)
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_8fd21">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_8fd21_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_8fd21_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_8fd21_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_8fd21_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_8fd21_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_8fd21_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_8fd21_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_8fd21_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_8fd21_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fd21_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_8fd21_row0_col0" class="data row0 col0" >38.000000</td>
#       <td id="T_8fd21_row0_col1" class="data row0 col1" >2.000000</td>
#       <td id="T_8fd21_row0_col2" class="data row0 col2" >18.000000</td>
#       <td id="T_8fd21_row0_col3" class="data row0 col3" >22.000000</td>
#       <td id="T_8fd21_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_8fd21_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8fd21_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_8fd21_row1_col0" class="data row1 col0" >19.000000</td>
#       <td id="T_8fd21_row1_col1" class="data row1 col1" >439.000000</td>
#       <td id="T_8fd21_row1_col2" class="data row1 col2" >6.000000</td>
#       <td id="T_8fd21_row1_col3" class="data row1 col3" >452.000000</td>
#       <td id="T_8fd21_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_8fd21_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to just create the below example: code is covered throughout the guide.
s = (
    df.style.hide([("Random", "Tumour"), ("Random", "Non-Tumour")], axis="columns")
    .format("{:.0f}")
    .set_table_styles(
        [
            {"selector": "", "props": "border-collapse: separate;"},
            {"selector": "caption", "props": "caption-side: bottom; font-size:1.3em;"},
            {
                "selector": ".index_name",
                "props": "font-style: italic; color: darkgrey; font-weight:normal;",
            },
            {
                "selector": "th:not(.index_name)",
                "props": "background-color: #000066; color: white;",
            },
            {"selector": "th.col_heading", "props": "text-align: center;"},
            {"selector": "th.col_heading.level0", "props": "font-size: 1.5em;"},
            {"selector": "th.col2", "props": "border-left: 1px solid white;"},
            {"selector": ".col2", "props": "border-left: 1px solid #000066;"},
            {"selector": "td", "props": "text-align: center; font-weight:bold;"},
            {"selector": ".true", "props": "background-color: #e6ffe6;"},
            {"selector": ".false", "props": "background-color: #ffe6e6;"},
            {"selector": ".border-red", "props": "border: 2px dashed red;"},
            {"selector": ".border-green", "props": "border: 2px dashed green;"},
            {"selector": "td:hover", "props": "background-color: #ffffb3;"},
        ]
    )
    .set_td_classes(
        pd.DataFrame(
            [
                ["true border-green", "false", "true", "false border-red", "", ""],
                ["false", "true", "false", "true", "", ""],
            ],
            index=df.index,
            columns=df.columns,
        )
    )
    .set_caption("Confusion matrix for multiple cancer prediction models.")
    .set_tooltips(
        pd.DataFrame(
            [
                [
                    "This model has a very strong true positive rate",
                    "",
                    "",
                    "This model's total number of false negatives is too high",
                    "",
                    "",
                ],
                ["", "", "", "", "", ""],
            ],
            index=df.index,
            columns=df.columns,
        ),
        css_class="pd-tt",
        props="visibility: hidden; "
        "position: absolute; z-index: 1; "
        "border: 1px solid #000066;"
        "background-color: white; color: #000066; font-size: 0.8em;"
        "transform: translate(0px, -24px); padding: 0.6em; border-radius: 0.5em;",
    )
)

# %%
s
# Out:
# <style type="text/css">
# #T_46efa  {
#   border-collapse: separate;
# }
# #T_46efa caption {
#   caption-side: bottom;
#   font-size: 1.3em;
# }
# #T_46efa .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_46efa th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_46efa th.col_heading {
#   text-align: center;
# }
# #T_46efa th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_46efa th.col2 {
#   border-left: 1px solid white;
# }
# #T_46efa .col2 {
#   border-left: 1px solid #000066;
# }
# #T_46efa td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_46efa .true {
#   background-color: #e6ffe6;
# }
# #T_46efa .false {
#   background-color: #ffe6e6;
# }
# #T_46efa .border-red {
#   border: 2px dashed red;
# }
# #T_46efa .border-green {
#   border: 2px dashed green;
# }
# #T_46efa td:hover {
#   background-color: #ffffb3;
# }
# #T_46efa .pd-tt {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   transform: translate(0px, -24px);
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_46efa #T_46efa_row0_col0:hover .pd-tt {
#   visibility: visible;
# }
# #T_46efa #T_46efa_row0_col0 .pd-tt::after {
#   content: "This model has a very strong true positive rate";
# }
# #T_46efa #T_46efa_row0_col3:hover .pd-tt {
#   visibility: visible;
# }
# #T_46efa #T_46efa_row0_col3 .pd-tt::after {
#   content: "This model's total number of false negatives is too high";
# }
# </style>
# <table id="T_46efa">
#   <caption>Confusion matrix for multiple cancer prediction models.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_46efa_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_46efa_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_46efa_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_46efa_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_46efa_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_46efa_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46efa_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_46efa_row0_col0" class="data row0 col0 true border-green" >38<span class="pd-tt"></span></td>
#       <td id="T_46efa_row0_col1" class="data row0 col1 false" >2<span class="pd-tt"></span></td>
#       <td id="T_46efa_row0_col2" class="data row0 col2 true" >18<span class="pd-tt"></span></td>
#       <td id="T_46efa_row0_col3" class="data row0 col3 false border-red" >22<span class="pd-tt"></span></td>
#     </tr>
#     <tr>
#       <th id="T_46efa_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_46efa_row1_col0" class="data row1 col0 false" >19<span class="pd-tt"></span></td>
#       <td id="T_46efa_row1_col1" class="data row1 col1 true" >439<span class="pd-tt"></span></td>
#       <td id="T_46efa_row1_col2" class="data row1 col2 false" >6<span class="pd-tt"></span></td>
#       <td id="T_46efa_row1_col3" class="data row1 col3 true" >452<span class="pd-tt"></span></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The first step we have taken is the create the Styler object from the DataFrame and then select the range of interest by hiding unwanted columns with [.hide()][hideidx].
#
# [hideidx]: ../reference/api/pandas.io.formats.style.Styler.hide.rst

# %%
s = df.style.format("{:.0f}").hide(
    [("Random", "Tumour"), ("Random", "Non-Tumour")], axis="columns"
)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ac13">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_1ac13_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_1ac13_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_1ac13_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_1ac13_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_1ac13_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_1ac13_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ac13_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_1ac13_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_1ac13_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_1ac13_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_1ac13_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_1ac13_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_1ac13_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_1ac13_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_1ac13_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_1ac13_row1_col3" class="data row1 col3" >452</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s.set_uuid("after_hide")
# Out:
# <style type="text/css">
# </style>
# <table id="T_after_hide">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_hide_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_hide_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_hide_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_hide_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_hide_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_hide_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_hide_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_hide_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_after_hide_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_after_hide_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_after_hide_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_after_hide_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_hide_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_after_hide_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_after_hide_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_after_hide_row1_col3" class="data row1 col3" >452</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Methods to Add Styles
#
# There are **3 primary methods of adding custom CSS styles** to [Styler][styler]:
#
# - Using [.set_table_styles()][table] to control broader areas of the table with specified internal CSS. Although table styles allow the flexibility to add CSS selectors and properties controlling all individual parts of the table, they are unwieldy for individual cell specifications. Also, note that table styles cannot be exported to Excel.
# - Using [.set_td_classes()][td_class] to directly link either external CSS classes to your data cells or link the internal CSS classes created by [.set_table_styles()][table]. See [here](#Setting-Classes-and-Linking-to-External-CSS). These cannot be used on column header rows or indexes, and also won't export to Excel.
# - Using the [.apply()][apply] and [.map()][map] functions to add direct internal CSS to specific data cells. See [here](#Styler-Functions). As of v1.4.0 there are also methods that work directly on column header rows or indexes: [.apply_index()][applyindex] and [.map_index()][mapindex]. Note that only these methods add styles that will export to Excel. These methods work in a similar way to [DataFrame.apply()][dfapply] and [DataFrame.map()][dfmap].
#
# [table]: ../reference/api/pandas.io.formats.style.Styler.set_table_styles.rst
# [styler]: ../reference/api/pandas.io.formats.style.Styler.rst
# [td_class]: ../reference/api/pandas.io.formats.style.Styler.set_td_classes.rst
# [apply]: ../reference/api/pandas.io.formats.style.Styler.apply.rst
# [map]: ../reference/api/pandas.io.formats.style.Styler.map.rst
# [applyindex]: ../reference/api/pandas.io.formats.style.Styler.apply_index.rst
# [mapindex]: ../reference/api/pandas.io.formats.style.Styler.map_index.rst
# [dfapply]: ../reference/api/pandas.DataFrame.apply.rst
# [dfmap]: ../reference/api/pandas.DataFrame.map.rst

# %% [markdown]
# ## Table Styles
#
# Table styles are flexible enough to control all individual parts of the table, including column headers and indexes.
# However, they can be unwieldy to type for individual data cells or for any kind of conditional formatting, so we recommend that table styles are used for broad styling, such as entire rows or columns at a time.
#
# Table styles are also used to control features which can apply to the whole table at once such as creating a generic hover functionality. The `:hover` pseudo-selector, as well as other pseudo-selectors, can only be used this way.
#
# To replicate the normal format of CSS selectors and properties (attribute value pairs), e.g.
#
# ```
# tr:hover {
#   background-color: #ffff99;
# }
# ```
#
# the necessary format to pass styles to [.set_table_styles()][table] is as a list of dicts, each with a CSS-selector tag and CSS-properties. Properties can either be a list of 2-tuples, or a regular CSS-string, for example:
#
# [table]: ../reference/api/pandas.io.formats.style.Styler.set_table_styles.rst

# %%
cell_hover = {  # for row hover use <tr> instead of <td>
    "selector": "td:hover",
    "props": [("background-color", "#ffffb3")],
}
index_names = {
    "selector": ".index_name",
    "props": "font-style: italic; color: darkgrey; font-weight:normal;",
}
headers = {
    "selector": "th:not(.index_name)",
    "props": "background-color: #000066; color: white;",
}
s.set_table_styles([cell_hover, index_names, headers])
# Out:
# <style type="text/css">
# #T_after_hide td:hover {
#   background-color: #ffffb3;
# }
# #T_after_hide .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_hide th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# </style>
# <table id="T_after_hide">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_hide_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_hide_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_hide_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_hide_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_hide_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_hide_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_hide_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_hide_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_after_hide_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_after_hide_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_after_hide_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_after_hide_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_hide_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_after_hide_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_after_hide_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_after_hide_row1_col3" class="data row1 col3" >452</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s.set_uuid("after_tab_styles1")
# Out:
# <style type="text/css">
# #T_after_tab_styles1 td:hover {
#   background-color: #ffffb3;
# }
# #T_after_tab_styles1 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_tab_styles1 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# </style>
# <table id="T_after_tab_styles1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_tab_styles1_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_tab_styles1_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_tab_styles1_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_tab_styles1_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_tab_styles1_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_tab_styles1_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_tab_styles1_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_tab_styles1_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_after_tab_styles1_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_after_tab_styles1_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_after_tab_styles1_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_after_tab_styles1_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_tab_styles1_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_after_tab_styles1_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_after_tab_styles1_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_after_tab_styles1_row1_col3" class="data row1 col3" >452</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Next we just add a couple more styling artifacts targeting specific parts of the table. Be careful here, since we are *chaining methods* we need to explicitly instruct the method **not to** ``overwrite`` the existing styles.

# %%
s.set_table_styles(
    [
        {"selector": "th.col_heading", "props": "text-align: center;"},
        {"selector": "th.col_heading.level0", "props": "font-size: 1.5em;"},
        {"selector": "td", "props": "text-align: center; font-weight: bold;"},
    ],
    overwrite=False,
)
# Out:
# <style type="text/css">
# #T_after_tab_styles1 td:hover {
#   background-color: #ffffb3;
# }
# #T_after_tab_styles1 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_tab_styles1 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_after_tab_styles1 th.col_heading {
#   text-align: center;
# }
# #T_after_tab_styles1 th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_after_tab_styles1 td {
#   text-align: center;
#   font-weight: bold;
# }
# </style>
# <table id="T_after_tab_styles1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_tab_styles1_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_tab_styles1_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_tab_styles1_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_tab_styles1_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_tab_styles1_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_tab_styles1_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_tab_styles1_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_tab_styles1_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_after_tab_styles1_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_after_tab_styles1_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_after_tab_styles1_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_after_tab_styles1_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_tab_styles1_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_after_tab_styles1_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_after_tab_styles1_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_after_tab_styles1_row1_col3" class="data row1 col3" >452</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s.set_uuid("after_tab_styles2")
# Out:
# <style type="text/css">
# #T_after_tab_styles2 td:hover {
#   background-color: #ffffb3;
# }
# #T_after_tab_styles2 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_tab_styles2 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_after_tab_styles2 th.col_heading {
#   text-align: center;
# }
# #T_after_tab_styles2 th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_after_tab_styles2 td {
#   text-align: center;
#   font-weight: bold;
# }
# </style>
# <table id="T_after_tab_styles2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_tab_styles2_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_tab_styles2_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_tab_styles2_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_tab_styles2_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_tab_styles2_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_tab_styles2_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_tab_styles2_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_tab_styles2_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_after_tab_styles2_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_after_tab_styles2_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_after_tab_styles2_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_after_tab_styles2_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_tab_styles2_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_after_tab_styles2_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_after_tab_styles2_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_after_tab_styles2_row1_col3" class="data row1 col3" >452</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# As a convenience method (*since version 1.2.0*) we can also pass a **dict** to [.set_table_styles()][table] which contains row or column keys. Behind the scenes Styler just indexes the keys and adds relevant `.col<m>` or `.row<n>` classes as necessary to the given CSS selectors.
#
# [table]: ../reference/api/pandas.io.formats.style.Styler.set_table_styles.rst

# %%
s.set_table_styles(
    {
        ("Regression", "Tumour"): [
            {"selector": "th", "props": "border-left: 1px solid white"},
            {"selector": "td", "props": "border-left: 1px solid #000066"},
        ]
    },
    overwrite=False,
    axis=0,
)
# Out:
# <style type="text/css">
# #T_after_tab_styles2 td:hover {
#   background-color: #ffffb3;
# }
# #T_after_tab_styles2 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_tab_styles2 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_after_tab_styles2 th.col_heading {
#   text-align: center;
# }
# #T_after_tab_styles2 th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_after_tab_styles2 td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_after_tab_styles2 th.col2 {
#   border-left: 1px solid white;
# }
# #T_after_tab_styles2 td.col2 {
#   border-left: 1px solid #000066;
# }
# </style>
# <table id="T_after_tab_styles2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_tab_styles2_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_tab_styles2_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_tab_styles2_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_tab_styles2_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_tab_styles2_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_tab_styles2_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_tab_styles2_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_tab_styles2_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_after_tab_styles2_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_after_tab_styles2_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_after_tab_styles2_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_after_tab_styles2_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_tab_styles2_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_after_tab_styles2_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_after_tab_styles2_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_after_tab_styles2_row1_col3" class="data row1 col3" >452</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s.set_uuid("xyz01")
# Out:
# <style type="text/css">
# #T_xyz01 td:hover {
#   background-color: #ffffb3;
# }
# #T_xyz01 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_xyz01 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_xyz01 th.col_heading {
#   text-align: center;
# }
# #T_xyz01 th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_xyz01 td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_xyz01 th.col2 {
#   border-left: 1px solid white;
# }
# #T_xyz01 td.col2 {
#   border-left: 1px solid #000066;
# }
# </style>
# <table id="T_xyz01">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_xyz01_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_xyz01_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_xyz01_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_xyz01_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_xyz01_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_xyz01_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_xyz01_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_xyz01_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_xyz01_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_xyz01_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_xyz01_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_xyz01_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_xyz01_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_xyz01_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_xyz01_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_xyz01_row1_col3" class="data row1 col3" >452</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Setting Classes and Linking to External CSS
#
# If you have designed a website then it is likely you will already have an external CSS file that controls the styling of table and cell objects within it. You may want to use these native files rather than duplicate all the CSS in python (and duplicate any maintenance work).
#
# ### Table Attributes
#
# It is very easy to add a `class` to the main `<table>` using [.set_table_attributes()][tableatt]. This method can also attach inline styles - read more in [CSS Hierarchies](#CSS-Hierarchies).
#
# [tableatt]: ../reference/api/pandas.io.formats.style.Styler.set_table_attributes.rst

# %%
out = s.set_table_attributes('class="my-table-cls"').to_html()
print(out[out.find("<table") :][:109])
# Out:
# <table id="T_xyz01" class="my-table-cls">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>

# %% [markdown]
# ### Data Cell CSS Classes
#
# *New in version 1.2.0*
#
# The [.set_td_classes()][tdclass] method accepts a DataFrame with matching indices and columns to the underlying [Styler][styler]'s DataFrame. That DataFrame will contain strings as css-classes to add to individual data cells: the `<td>` elements of the `<table>`. Rather than use external CSS we will create our classes internally and add them to table style. We will save adding the borders until the [section on tooltips](#Tooltips-and-Captions).
#
# [tdclass]: ../reference/api/pandas.io.formats.style.Styler.set_td_classes.rst
# [styler]: ../reference/api/pandas.io.formats.style.Styler.rst

# %%
s.set_table_styles(
    [  # create internal CSS classes
        {"selector": ".true", "props": "background-color: #e6ffe6;"},
        {"selector": ".false", "props": "background-color: #ffe6e6;"},
    ],
    overwrite=False,
)
cell_color = pd.DataFrame(
    [["true ", "false ", "true ", "false "], ["false ", "true ", "false ", "true "]],
    index=df.index,
    columns=df.columns[:4],
)
s.set_td_classes(cell_color)
# Out:
# <style type="text/css">
# #T_xyz01 td:hover {
#   background-color: #ffffb3;
# }
# #T_xyz01 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_xyz01 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_xyz01 th.col_heading {
#   text-align: center;
# }
# #T_xyz01 th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_xyz01 td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_xyz01 th.col2 {
#   border-left: 1px solid white;
# }
# #T_xyz01 td.col2 {
#   border-left: 1px solid #000066;
# }
# #T_xyz01 .true {
#   background-color: #e6ffe6;
# }
# #T_xyz01 .false {
#   background-color: #ffe6e6;
# }
# </style>
# <table id="T_xyz01" class="my-table-cls">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_xyz01_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_xyz01_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_xyz01_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_xyz01_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_xyz01_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_xyz01_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_xyz01_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_xyz01_row0_col0" class="data row0 col0 true " >38</td>
#       <td id="T_xyz01_row0_col1" class="data row0 col1 false " >2</td>
#       <td id="T_xyz01_row0_col2" class="data row0 col2 true " >18</td>
#       <td id="T_xyz01_row0_col3" class="data row0 col3 false " >22</td>
#     </tr>
#     <tr>
#       <th id="T_xyz01_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_xyz01_row1_col0" class="data row1 col0 false " >19</td>
#       <td id="T_xyz01_row1_col1" class="data row1 col1 true " >439</td>
#       <td id="T_xyz01_row1_col2" class="data row1 col2 false " >6</td>
#       <td id="T_xyz01_row1_col3" class="data row1 col3 true " >452</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s.set_uuid("after_classes")
# Out:
# <style type="text/css">
# #T_after_classes td:hover {
#   background-color: #ffffb3;
# }
# #T_after_classes .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_classes th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_after_classes th.col_heading {
#   text-align: center;
# }
# #T_after_classes th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_after_classes td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_after_classes th.col2 {
#   border-left: 1px solid white;
# }
# #T_after_classes td.col2 {
#   border-left: 1px solid #000066;
# }
# #T_after_classes .true {
#   background-color: #e6ffe6;
# }
# #T_after_classes .false {
#   background-color: #ffe6e6;
# }
# </style>
# <table id="T_after_classes" class="my-table-cls">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_classes_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_classes_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_classes_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_classes_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_classes_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_classes_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_classes_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_classes_row0_col0" class="data row0 col0 true " >38</td>
#       <td id="T_after_classes_row0_col1" class="data row0 col1 false " >2</td>
#       <td id="T_after_classes_row0_col2" class="data row0 col2 true " >18</td>
#       <td id="T_after_classes_row0_col3" class="data row0 col3 false " >22</td>
#     </tr>
#     <tr>
#       <th id="T_after_classes_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_classes_row1_col0" class="data row1 col0 false " >19</td>
#       <td id="T_after_classes_row1_col1" class="data row1 col1 true " >439</td>
#       <td id="T_after_classes_row1_col2" class="data row1 col2 false " >6</td>
#       <td id="T_after_classes_row1_col3" class="data row1 col3 true " >452</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Styler Functions
#
# ### Acting on Data
#
# We use the following methods to pass your style functions. Both of those methods take a function (and some other keyword arguments) and apply it to the DataFrame in a certain way, rendering CSS styles.
#
# - [.map()][map] (elementwise): accepts a function that takes a single value and returns a string with the CSS attribute-value pair.
# - [.apply()][apply] (column-/row-/table-wise): accepts a function that takes a Series or DataFrame and returns a Series, DataFrame, or numpy array with an identical shape where each element is a string with a CSS attribute-value pair. This method passes each column or row of your DataFrame one-at-a-time or the entire table at once, depending on the `axis` keyword argument. For columnwise use `axis=0`, rowwise use `axis=1`, and for the entire table at once use `axis=None`.
#
# This method is powerful for applying multiple, complex logic to data cells. We create a new DataFrame to demonstrate this.
#
# [apply]: ../reference/api/pandas.io.formats.style.Styler.apply.rst
# [map]: ../reference/api/pandas.io.formats.style.Styler.map.rst

# %%
df2 = pd.DataFrame(
    np.random.default_rng(0).standard_normal((10, 4)), columns=["A", "B", "C", "D"]
)
df2.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_20c1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20c1b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_20c1b_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_20c1b_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_20c1b_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20c1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20c1b_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_20c1b_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_20c1b_row0_col2" class="data row0 col2" >0.640423</td>
#       <td id="T_20c1b_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_20c1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20c1b_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_20c1b_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_20c1b_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_20c1b_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_20c1b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20c1b_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_20c1b_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_20c1b_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_20c1b_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_20c1b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20c1b_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_20c1b_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_20c1b_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_20c1b_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_20c1b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20c1b_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_20c1b_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_20c1b_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_20c1b_row4_col3" class="data row4 col3" >1.042513</td>
#     </tr>
#     <tr>
#       <th id="T_20c1b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20c1b_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_20c1b_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_20c1b_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_20c1b_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_20c1b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20c1b_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_20c1b_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_20c1b_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_20c1b_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_20c1b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20c1b_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_20c1b_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_20c1b_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_20c1b_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_20c1b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20c1b_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_20c1b_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_20c1b_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_20c1b_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_20c1b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20c1b_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_20c1b_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_20c1b_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_20c1b_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# For example we can build a function that colors text if it is negative, and chain this with a function that partially fades cells of negligible value. Since this looks at each element in turn we use ``map``.

# %%
def style_negative(v, props=""):
    return props if v < 0 else None


s2 = df2.style.map(style_negative, props="color:red;").map(
    lambda v: "opacity: 20%;" if (v < 0.3) and (v > -0.3) else None
)
s2
# Out:
# <style type="text/css">
# #T_e4f1c_row0_col0, #T_e4f1c_row0_col3, #T_e4f1c_row2_col3, #T_e4f1c_row6_col1, #T_e4f1c_row7_col1, #T_e4f1c_row8_col2 {
#   opacity: 20%;
# }
# #T_e4f1c_row0_col1, #T_e4f1c_row3_col1, #T_e4f1c_row5_col0, #T_e4f1c_row7_col3, #T_e4f1c_row8_col0, #T_e4f1c_row9_col1 {
#   color: red;
#   opacity: 20%;
# }
# #T_e4f1c_row1_col0, #T_e4f1c_row2_col0, #T_e4f1c_row2_col1, #T_e4f1c_row2_col2, #T_e4f1c_row3_col0, #T_e4f1c_row3_col2, #T_e4f1c_row3_col3, #T_e4f1c_row4_col0, #T_e4f1c_row4_col1, #T_e4f1c_row5_col2, #T_e4f1c_row6_col2, #T_e4f1c_row6_col3, #T_e4f1c_row7_col0, #T_e4f1c_row7_col2, #T_e4f1c_row9_col0 {
#   color: red;
# }
# </style>
# <table id="T_e4f1c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4f1c_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e4f1c_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_e4f1c_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_e4f1c_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4f1c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4f1c_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_e4f1c_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_e4f1c_row0_col2" class="data row0 col2" >0.640423</td>
#       <td id="T_e4f1c_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_e4f1c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4f1c_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_e4f1c_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_e4f1c_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_e4f1c_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_e4f1c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4f1c_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_e4f1c_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_e4f1c_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_e4f1c_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_e4f1c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4f1c_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_e4f1c_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_e4f1c_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_e4f1c_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_e4f1c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e4f1c_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_e4f1c_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_e4f1c_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_e4f1c_row4_col3" class="data row4 col3" >1.042513</td>
#     </tr>
#     <tr>
#       <th id="T_e4f1c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e4f1c_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_e4f1c_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_e4f1c_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_e4f1c_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_e4f1c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e4f1c_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_e4f1c_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_e4f1c_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_e4f1c_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_e4f1c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e4f1c_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_e4f1c_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_e4f1c_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_e4f1c_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_e4f1c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e4f1c_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_e4f1c_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_e4f1c_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_e4f1c_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_e4f1c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e4f1c_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_e4f1c_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_e4f1c_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_e4f1c_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s2.set_uuid("after_applymap")
# Out:
# <style type="text/css">
# #T_after_applymap_row0_col0, #T_after_applymap_row0_col3, #T_after_applymap_row2_col3, #T_after_applymap_row6_col1, #T_after_applymap_row7_col1, #T_after_applymap_row8_col2 {
#   opacity: 20%;
# }
# #T_after_applymap_row0_col1, #T_after_applymap_row3_col1, #T_after_applymap_row5_col0, #T_after_applymap_row7_col3, #T_after_applymap_row8_col0, #T_after_applymap_row9_col1 {
#   color: red;
#   opacity: 20%;
# }
# #T_after_applymap_row1_col0, #T_after_applymap_row2_col0, #T_after_applymap_row2_col1, #T_after_applymap_row2_col2, #T_after_applymap_row3_col0, #T_after_applymap_row3_col2, #T_after_applymap_row3_col3, #T_after_applymap_row4_col0, #T_after_applymap_row4_col1, #T_after_applymap_row5_col2, #T_after_applymap_row6_col2, #T_after_applymap_row6_col3, #T_after_applymap_row7_col0, #T_after_applymap_row7_col2, #T_after_applymap_row9_col0 {
#   color: red;
# }
# </style>
# <table id="T_after_applymap">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_after_applymap_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_after_applymap_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_after_applymap_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_after_applymap_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_applymap_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_after_applymap_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_after_applymap_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_after_applymap_row0_col2" class="data row0 col2" >0.640423</td>
#       <td id="T_after_applymap_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_after_applymap_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_after_applymap_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_after_applymap_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_after_applymap_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_after_applymap_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_after_applymap_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_after_applymap_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_after_applymap_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_after_applymap_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_after_applymap_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_after_applymap_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_after_applymap_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_after_applymap_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_after_applymap_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_after_applymap_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_after_applymap_row4_col3" class="data row4 col3" >1.042513</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_after_applymap_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_after_applymap_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_after_applymap_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_after_applymap_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_after_applymap_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_after_applymap_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_after_applymap_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_after_applymap_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_after_applymap_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_after_applymap_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_after_applymap_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_after_applymap_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_after_applymap_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_after_applymap_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_after_applymap_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_after_applymap_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_after_applymap_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_after_applymap_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_after_applymap_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_after_applymap_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can also build a function that highlights the maximum value across rows, cols, and the DataFrame all at once. In this case we use ``apply``. Below we highlight the maximum in a column.

# %%
def highlight_max(s, props=""):
    return np.where(s == np.nanmax(s.values), props, "")


s2.apply(highlight_max, props="color:white;background-color:darkblue", axis=0)
# Out:
# <style type="text/css">
# #T_after_applymap_row0_col0, #T_after_applymap_row0_col3, #T_after_applymap_row2_col3, #T_after_applymap_row6_col1, #T_after_applymap_row7_col1, #T_after_applymap_row8_col2 {
#   opacity: 20%;
# }
# #T_after_applymap_row0_col1, #T_after_applymap_row3_col1, #T_after_applymap_row5_col0, #T_after_applymap_row7_col3, #T_after_applymap_row8_col0, #T_after_applymap_row9_col1 {
#   color: red;
#   opacity: 20%;
# }
# #T_after_applymap_row1_col0, #T_after_applymap_row2_col0, #T_after_applymap_row2_col1, #T_after_applymap_row2_col2, #T_after_applymap_row3_col0, #T_after_applymap_row3_col2, #T_after_applymap_row3_col3, #T_after_applymap_row4_col0, #T_after_applymap_row4_col1, #T_after_applymap_row5_col2, #T_after_applymap_row6_col2, #T_after_applymap_row6_col3, #T_after_applymap_row7_col0, #T_after_applymap_row7_col2, #T_after_applymap_row9_col0 {
#   color: red;
# }
# #T_after_applymap_row1_col2, #T_after_applymap_row5_col1, #T_after_applymap_row6_col0, #T_after_applymap_row9_col3 {
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_after_applymap">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_after_applymap_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_after_applymap_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_after_applymap_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_after_applymap_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_applymap_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_after_applymap_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_after_applymap_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_after_applymap_row0_col2" class="data row0 col2" >0.640423</td>
#       <td id="T_after_applymap_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_after_applymap_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_after_applymap_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_after_applymap_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_after_applymap_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_after_applymap_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_after_applymap_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_after_applymap_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_after_applymap_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_after_applymap_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_after_applymap_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_after_applymap_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_after_applymap_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_after_applymap_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_after_applymap_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_after_applymap_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_after_applymap_row4_col3" class="data row4 col3" >1.042513</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_after_applymap_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_after_applymap_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_after_applymap_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_after_applymap_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_after_applymap_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_after_applymap_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_after_applymap_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_after_applymap_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_after_applymap_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_after_applymap_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_after_applymap_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_after_applymap_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_after_applymap_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_after_applymap_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_after_applymap_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_after_applymap_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_after_applymap_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_after_applymap_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_after_applymap_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_after_applymap_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_after_applymap_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s2.set_uuid("after_apply")
# Out:
# <style type="text/css">
# #T_after_apply_row0_col0, #T_after_apply_row0_col3, #T_after_apply_row2_col3, #T_after_apply_row6_col1, #T_after_apply_row7_col1, #T_after_apply_row8_col2 {
#   opacity: 20%;
# }
# #T_after_apply_row0_col1, #T_after_apply_row3_col1, #T_after_apply_row5_col0, #T_after_apply_row7_col3, #T_after_apply_row8_col0, #T_after_apply_row9_col1 {
#   color: red;
#   opacity: 20%;
# }
# #T_after_apply_row1_col0, #T_after_apply_row2_col0, #T_after_apply_row2_col1, #T_after_apply_row2_col2, #T_after_apply_row3_col0, #T_after_apply_row3_col2, #T_after_apply_row3_col3, #T_after_apply_row4_col0, #T_after_apply_row4_col1, #T_after_apply_row5_col2, #T_after_apply_row6_col2, #T_after_apply_row6_col3, #T_after_apply_row7_col0, #T_after_apply_row7_col2, #T_after_apply_row9_col0 {
#   color: red;
# }
# #T_after_apply_row1_col2, #T_after_apply_row5_col1, #T_after_apply_row6_col0, #T_after_apply_row9_col3 {
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_after_apply">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_after_apply_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_after_apply_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_after_apply_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_after_apply_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_apply_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_after_apply_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_after_apply_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_after_apply_row0_col2" class="data row0 col2" >0.640423</td>
#       <td id="T_after_apply_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_after_apply_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_after_apply_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_after_apply_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_after_apply_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_after_apply_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_after_apply_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_after_apply_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_after_apply_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_after_apply_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_after_apply_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_after_apply_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_after_apply_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_after_apply_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_after_apply_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_after_apply_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_after_apply_row4_col3" class="data row4 col3" >1.042513</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_after_apply_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_after_apply_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_after_apply_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_after_apply_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_after_apply_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_after_apply_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_after_apply_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_after_apply_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_after_apply_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_after_apply_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_after_apply_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_after_apply_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_after_apply_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_after_apply_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_after_apply_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_after_apply_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_after_apply_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_after_apply_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_after_apply_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_after_apply_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can use the same function across the different axes, highlighting here the DataFrame maximum in purple, and row maximums in pink.

# %%
s2.apply(highlight_max, props="color:white;background-color:pink;", axis=1).apply(
    highlight_max, props="color:white;background-color:purple", axis=None
)
# Out:
# <style type="text/css">
# #T_after_apply_row0_col0, #T_after_apply_row0_col3, #T_after_apply_row6_col1, #T_after_apply_row8_col2 {
#   opacity: 20%;
# }
# #T_after_apply_row0_col1, #T_after_apply_row5_col0, #T_after_apply_row7_col3, #T_after_apply_row8_col0, #T_after_apply_row9_col1 {
#   color: red;
#   opacity: 20%;
# }
# #T_after_apply_row0_col2, #T_after_apply_row4_col3, #T_after_apply_row8_col1 {
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_row1_col0, #T_after_apply_row2_col0, #T_after_apply_row2_col1, #T_after_apply_row2_col2, #T_after_apply_row3_col0, #T_after_apply_row3_col2, #T_after_apply_row3_col3, #T_after_apply_row4_col0, #T_after_apply_row4_col1, #T_after_apply_row5_col2, #T_after_apply_row6_col2, #T_after_apply_row6_col3, #T_after_apply_row7_col0, #T_after_apply_row7_col2, #T_after_apply_row9_col0 {
#   color: red;
# }
# #T_after_apply_row1_col2, #T_after_apply_row5_col1, #T_after_apply_row6_col0 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_row2_col3, #T_after_apply_row7_col1 {
#   opacity: 20%;
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_row3_col1 {
#   color: red;
#   opacity: 20%;
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_row9_col3 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
# }
# </style>
# <table id="T_after_apply">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_after_apply_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_after_apply_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_after_apply_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_after_apply_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_apply_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_after_apply_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_after_apply_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_after_apply_row0_col2" class="data row0 col2" >0.640423</td>
#       <td id="T_after_apply_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_after_apply_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_after_apply_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_after_apply_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_after_apply_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_after_apply_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_after_apply_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_after_apply_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_after_apply_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_after_apply_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_after_apply_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_after_apply_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_after_apply_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_after_apply_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_after_apply_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_after_apply_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_after_apply_row4_col3" class="data row4 col3" >1.042513</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_after_apply_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_after_apply_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_after_apply_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_after_apply_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_after_apply_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_after_apply_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_after_apply_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_after_apply_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_after_apply_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_after_apply_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_after_apply_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_after_apply_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_after_apply_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_after_apply_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_after_apply_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_after_apply_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_after_apply_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_after_apply_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_after_apply_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_after_apply_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s2.set_uuid("after_apply_again")
# Out:
# <style type="text/css">
# #T_after_apply_again_row0_col0, #T_after_apply_again_row0_col3, #T_after_apply_again_row6_col1, #T_after_apply_again_row8_col2 {
#   opacity: 20%;
# }
# #T_after_apply_again_row0_col1, #T_after_apply_again_row5_col0, #T_after_apply_again_row7_col3, #T_after_apply_again_row8_col0, #T_after_apply_again_row9_col1 {
#   color: red;
#   opacity: 20%;
# }
# #T_after_apply_again_row0_col2, #T_after_apply_again_row4_col3, #T_after_apply_again_row8_col1 {
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_again_row1_col0, #T_after_apply_again_row2_col0, #T_after_apply_again_row2_col1, #T_after_apply_again_row2_col2, #T_after_apply_again_row3_col0, #T_after_apply_again_row3_col2, #T_after_apply_again_row3_col3, #T_after_apply_again_row4_col0, #T_after_apply_again_row4_col1, #T_after_apply_again_row5_col2, #T_after_apply_again_row6_col2, #T_after_apply_again_row6_col3, #T_after_apply_again_row7_col0, #T_after_apply_again_row7_col2, #T_after_apply_again_row9_col0 {
#   color: red;
# }
# #T_after_apply_again_row1_col2, #T_after_apply_again_row5_col1, #T_after_apply_again_row6_col0 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_again_row2_col3, #T_after_apply_again_row7_col1 {
#   opacity: 20%;
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_again_row3_col1 {
#   color: red;
#   opacity: 20%;
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_again_row9_col3 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
# }
# </style>
# <table id="T_after_apply_again">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_after_apply_again_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_after_apply_again_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_after_apply_again_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_after_apply_again_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_apply_again_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_after_apply_again_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_after_apply_again_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_after_apply_again_row0_col2" class="data row0 col2" >0.640423</td>
#       <td id="T_after_apply_again_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_after_apply_again_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_after_apply_again_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_after_apply_again_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_after_apply_again_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_after_apply_again_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_after_apply_again_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_after_apply_again_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_after_apply_again_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_after_apply_again_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_after_apply_again_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_after_apply_again_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_after_apply_again_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_after_apply_again_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_after_apply_again_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_after_apply_again_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_after_apply_again_row4_col3" class="data row4 col3" >1.042513</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_after_apply_again_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_after_apply_again_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_after_apply_again_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_after_apply_again_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_after_apply_again_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_after_apply_again_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_after_apply_again_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_after_apply_again_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_after_apply_again_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_after_apply_again_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_after_apply_again_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_after_apply_again_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_after_apply_again_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_after_apply_again_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_after_apply_again_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_after_apply_again_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_after_apply_again_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_after_apply_again_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_after_apply_again_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_after_apply_again_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This last example shows how some styles have been overwritten by others. In general the most recent style applied is active but you can read more in the [section on CSS hierarchies](#CSS-Hierarchies). You can also apply these styles to more granular parts of the DataFrame - read more in section on [subset slicing](#Finer-Control-with-Slicing).
#
# It is possible to replicate some of this functionality using just classes but it can be more cumbersome. See [item 3)  of Optimization](#Optimization)
#
# <div class="alert alert-info">
#
# *Debugging Tip*: If you're having trouble writing your style function, try just passing it into ``DataFrame.apply``. Internally, ``Styler.apply`` uses ``DataFrame.apply`` so the result should be the same, and with ``DataFrame.apply`` you will be able to inspect the CSS string output of your intended function in each cell.
#
# </div>

# %% [markdown]
# ### Acting on the Index and Column Headers
#
# Similar application is achieved for headers by using:
#
# - [.map_index()][mapindex] (elementwise): accepts a function that takes a single value and returns a string with the CSS attribute-value pair.
# - [.apply_index()][applyindex] (level-wise): accepts a function that takes a Series and returns a Series, or numpy array with an identical shape where each element is a string with a CSS attribute-value pair. This method passes each level of your Index one-at-a-time. To style the index use `axis=0` and to style the column headers use `axis=1`.
#
# You can select a `level` of a `MultiIndex` but currently no similar `subset` application is available for these methods.
#
# [applyindex]: ../reference/api/pandas.io.formats.style.Styler.apply_index.rst
# [mapindex]: ../reference/api/pandas.io.formats.style.Styler.map_index.rst

# %%
s2.map_index(lambda v: "color:pink;" if v > 4 else "color:darkblue;", axis=0)
s2.apply_index(
    lambda s: np.where(s.isin(["A", "B"]), "color:pink;", "color:darkblue;"), axis=1
)
# Out:
# <style type="text/css">
# #T_after_apply_again_row0_col0, #T_after_apply_again_row0_col3, #T_after_apply_again_row6_col1, #T_after_apply_again_row8_col2 {
#   opacity: 20%;
# }
# #T_after_apply_again_row0_col1, #T_after_apply_again_row5_col0, #T_after_apply_again_row7_col3, #T_after_apply_again_row8_col0, #T_after_apply_again_row9_col1 {
#   color: red;
#   opacity: 20%;
# }
# #T_after_apply_again_row0_col2, #T_after_apply_again_row4_col3, #T_after_apply_again_row8_col1 {
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_again_row1_col0, #T_after_apply_again_row2_col0, #T_after_apply_again_row2_col1, #T_after_apply_again_row2_col2, #T_after_apply_again_row3_col0, #T_after_apply_again_row3_col2, #T_after_apply_again_row3_col3, #T_after_apply_again_row4_col0, #T_after_apply_again_row4_col1, #T_after_apply_again_row5_col2, #T_after_apply_again_row6_col2, #T_after_apply_again_row6_col3, #T_after_apply_again_row7_col0, #T_after_apply_again_row7_col2, #T_after_apply_again_row9_col0 {
#   color: red;
# }
# #T_after_apply_again_row1_col2, #T_after_apply_again_row5_col1, #T_after_apply_again_row6_col0 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_again_row2_col3, #T_after_apply_again_row7_col1 {
#   opacity: 20%;
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_again_row3_col1 {
#   color: red;
#   opacity: 20%;
#   color: white;
#   background-color: pink;
# }
# #T_after_apply_again_row9_col3 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
# }
# #T_after_apply_again_level0_row0, #T_after_apply_again_level0_row1, #T_after_apply_again_level0_row2, #T_after_apply_again_level0_row3, #T_after_apply_again_level0_row4 {
#   color: darkblue;
# }
# #T_after_apply_again_level0_row5, #T_after_apply_again_level0_row6, #T_after_apply_again_level0_row7, #T_after_apply_again_level0_row8, #T_after_apply_again_level0_row9 {
#   color: pink;
# }
# #T_after_apply_again_level0_col0, #T_after_apply_again_level0_col1 {
#   color: pink;
# }
# #T_after_apply_again_level0_col2, #T_after_apply_again_level0_col3 {
#   color: darkblue;
# }
# </style>
# <table id="T_after_apply_again">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_after_apply_again_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_after_apply_again_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_after_apply_again_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_after_apply_again_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_apply_again_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_after_apply_again_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_after_apply_again_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_after_apply_again_row0_col2" class="data row0 col2" >0.640423</td>
#       <td id="T_after_apply_again_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_after_apply_again_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_after_apply_again_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_after_apply_again_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_after_apply_again_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_after_apply_again_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_after_apply_again_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_after_apply_again_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_after_apply_again_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_after_apply_again_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_after_apply_again_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_after_apply_again_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_after_apply_again_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_after_apply_again_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_after_apply_again_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_after_apply_again_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_after_apply_again_row4_col3" class="data row4 col3" >1.042513</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_after_apply_again_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_after_apply_again_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_after_apply_again_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_after_apply_again_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_after_apply_again_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_after_apply_again_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_after_apply_again_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_after_apply_again_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_after_apply_again_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_after_apply_again_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_after_apply_again_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_after_apply_again_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_after_apply_again_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_after_apply_again_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_after_apply_again_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_after_apply_again_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_after_apply_again_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_after_apply_again_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_after_apply_again_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_after_apply_again_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_after_apply_again_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Tooltips and Captions
#
# Table captions can be added with the [.set_caption()][caption] method. You can use table styles to control the CSS relevant to the caption.
#
# [caption]: ../reference/api/pandas.io.formats.style.Styler.set_caption.rst

# %%
s.set_caption(
    "Confusion matrix for multiple cancer prediction models."
).set_table_styles(
    [{"selector": "caption", "props": "caption-side: bottom; font-size:1.25em;"}],
    overwrite=False,
)
# Out:
# <style type="text/css">
# #T_after_classes td:hover {
#   background-color: #ffffb3;
# }
# #T_after_classes .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_classes th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_after_classes th.col_heading {
#   text-align: center;
# }
# #T_after_classes th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_after_classes td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_after_classes th.col2 {
#   border-left: 1px solid white;
# }
# #T_after_classes td.col2 {
#   border-left: 1px solid #000066;
# }
# #T_after_classes .true {
#   background-color: #e6ffe6;
# }
# #T_after_classes .false {
#   background-color: #ffe6e6;
# }
# #T_after_classes caption {
#   caption-side: bottom;
#   font-size: 1.25em;
# }
# </style>
# <table id="T_after_classes" class="my-table-cls">
#   <caption>Confusion matrix for multiple cancer prediction models.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_classes_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_classes_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_classes_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_classes_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_classes_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_classes_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_classes_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_classes_row0_col0" class="data row0 col0 true " >38</td>
#       <td id="T_after_classes_row0_col1" class="data row0 col1 false " >2</td>
#       <td id="T_after_classes_row0_col2" class="data row0 col2 true " >18</td>
#       <td id="T_after_classes_row0_col3" class="data row0 col3 false " >22</td>
#     </tr>
#     <tr>
#       <th id="T_after_classes_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_classes_row1_col0" class="data row1 col0 false " >19</td>
#       <td id="T_after_classes_row1_col1" class="data row1 col1 true " >439</td>
#       <td id="T_after_classes_row1_col2" class="data row1 col2 false " >6</td>
#       <td id="T_after_classes_row1_col3" class="data row1 col3 true " >452</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s.set_uuid("after_caption")
# Out:
# <style type="text/css">
# #T_after_caption td:hover {
#   background-color: #ffffb3;
# }
# #T_after_caption .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_caption th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_after_caption th.col_heading {
#   text-align: center;
# }
# #T_after_caption th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_after_caption td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_after_caption th.col2 {
#   border-left: 1px solid white;
# }
# #T_after_caption td.col2 {
#   border-left: 1px solid #000066;
# }
# #T_after_caption .true {
#   background-color: #e6ffe6;
# }
# #T_after_caption .false {
#   background-color: #ffe6e6;
# }
# #T_after_caption caption {
#   caption-side: bottom;
#   font-size: 1.25em;
# }
# </style>
# <table id="T_after_caption" class="my-table-cls">
#   <caption>Confusion matrix for multiple cancer prediction models.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_caption_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_caption_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_caption_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_caption_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_caption_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_caption_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_caption_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_caption_row0_col0" class="data row0 col0 true " >38</td>
#       <td id="T_after_caption_row0_col1" class="data row0 col1 false " >2</td>
#       <td id="T_after_caption_row0_col2" class="data row0 col2 true " >18</td>
#       <td id="T_after_caption_row0_col3" class="data row0 col3 false " >22</td>
#     </tr>
#     <tr>
#       <th id="T_after_caption_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_caption_row1_col0" class="data row1 col0 false " >19</td>
#       <td id="T_after_caption_row1_col1" class="data row1 col1 true " >439</td>
#       <td id="T_after_caption_row1_col2" class="data row1 col2 false " >6</td>
#       <td id="T_after_caption_row1_col3" class="data row1 col3 true " >452</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Adding tooltips (*since version 1.3.0*) can be done using the [.set_tooltips()][tooltips] method in the same way you can add CSS classes to data cells by providing a string based DataFrame with intersecting indices and columns. You don't have to specify a `css_class` name or any css `props` for the tooltips, since there are standard defaults, but the option is there if you want more visual control.
#
# [tooltips]: ../reference/api/pandas.io.formats.style.Styler.set_tooltips.rst

# %%
tt = pd.DataFrame(
    [
        [
            "This model has a very strong true positive rate",
            "This model's total number of false negatives is too high",
        ]
    ],
    index=["Tumour (Positive)"],
    columns=df.columns[[0, 3]],
)
s.set_tooltips(
    tt,
    props="visibility: hidden; position: absolute; z-index: 1; "
    "border: 1px solid #000066;"
    "background-color: white; color: #000066; font-size: 0.8em;"
    "transform: translate(0px, -24px); padding: 0.6em; "
    "border-radius: 0.5em;",
)
# Out:
# <style type="text/css">
# #T_after_caption td:hover {
#   background-color: #ffffb3;
# }
# #T_after_caption .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_caption th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_after_caption th.col_heading {
#   text-align: center;
# }
# #T_after_caption th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_after_caption td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_after_caption th.col2 {
#   border-left: 1px solid white;
# }
# #T_after_caption td.col2 {
#   border-left: 1px solid #000066;
# }
# #T_after_caption .true {
#   background-color: #e6ffe6;
# }
# #T_after_caption .false {
#   background-color: #ffe6e6;
# }
# #T_after_caption caption {
#   caption-side: bottom;
#   font-size: 1.25em;
# }
# #T_after_caption .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   transform: translate(0px, -24px);
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_after_caption #T_after_caption_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_after_caption #T_after_caption_row0_col0 .pd-t::after {
#   content: "This model has a very strong true positive rate";
# }
# #T_after_caption #T_after_caption_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_after_caption #T_after_caption_row0_col3 .pd-t::after {
#   content: "This model's total number of false negatives is too high";
# }
# </style>
# <table id="T_after_caption" class="my-table-cls">
#   <caption>Confusion matrix for multiple cancer prediction models.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_caption_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_caption_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_caption_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_caption_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_caption_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_caption_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_caption_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_caption_row0_col0" class="data row0 col0 true " >38<span class="pd-t"></span></td>
#       <td id="T_after_caption_row0_col1" class="data row0 col1 false " >2<span class="pd-t"></span></td>
#       <td id="T_after_caption_row0_col2" class="data row0 col2 true " >18<span class="pd-t"></span></td>
#       <td id="T_after_caption_row0_col3" class="data row0 col3 false " >22<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_after_caption_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_caption_row1_col0" class="data row1 col0 false " >19<span class="pd-t"></span></td>
#       <td id="T_after_caption_row1_col1" class="data row1 col1 true " >439<span class="pd-t"></span></td>
#       <td id="T_after_caption_row1_col2" class="data row1 col2 false " >6<span class="pd-t"></span></td>
#       <td id="T_after_caption_row1_col3" class="data row1 col3 true " >452<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s.set_uuid("after_tooltips")
# Out:
# <style type="text/css">
# #T_after_tooltips td:hover {
#   background-color: #ffffb3;
# }
# #T_after_tooltips .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_tooltips th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_after_tooltips th.col_heading {
#   text-align: center;
# }
# #T_after_tooltips th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_after_tooltips td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_after_tooltips th.col2 {
#   border-left: 1px solid white;
# }
# #T_after_tooltips td.col2 {
#   border-left: 1px solid #000066;
# }
# #T_after_tooltips .true {
#   background-color: #e6ffe6;
# }
# #T_after_tooltips .false {
#   background-color: #ffe6e6;
# }
# #T_after_tooltips caption {
#   caption-side: bottom;
#   font-size: 1.25em;
# }
# #T_after_tooltips .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   transform: translate(0px, -24px);
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_after_tooltips #T_after_tooltips_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_after_tooltips #T_after_tooltips_row0_col0 .pd-t::after {
#   content: "This model has a very strong true positive rate";
# }
# #T_after_tooltips #T_after_tooltips_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_after_tooltips #T_after_tooltips_row0_col3 .pd-t::after {
#   content: "This model's total number of false negatives is too high";
# }
# </style>
# <table id="T_after_tooltips" class="my-table-cls">
#   <caption>Confusion matrix for multiple cancer prediction models.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_tooltips_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_tooltips_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_tooltips_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_tooltips_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_tooltips_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_tooltips_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_tooltips_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_tooltips_row0_col0" class="data row0 col0 true " >38<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row0_col1" class="data row0 col1 false " >2<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row0_col2" class="data row0 col2 true " >18<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row0_col3" class="data row0 col3 false " >22<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_after_tooltips_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_tooltips_row1_col0" class="data row1 col0 false " >19<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row1_col1" class="data row1 col1 true " >439<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row1_col2" class="data row1 col2 false " >6<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row1_col3" class="data row1 col3 true " >452<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The only thing left to do for our table is to add the highlighting borders to draw the audience attention to the tooltips. We will create internal CSS classes as before using table styles. **Setting classes always overwrites** so we need to make sure we add the previous classes.

# %%
s.set_table_styles(
    [  # create internal CSS classes
        {"selector": ".border-red", "props": "border: 2px dashed red;"},
        {"selector": ".border-green", "props": "border: 2px dashed green;"},
    ],
    overwrite=False,
)
cell_border = pd.DataFrame(
    [["border-green ", " ", " ", "border-red "], [" ", " ", " ", " "]],
    index=df.index,
    columns=df.columns[:4],
)
s.set_td_classes(cell_color + cell_border)
# Out:
# <style type="text/css">
# #T_after_tooltips td:hover {
#   background-color: #ffffb3;
# }
# #T_after_tooltips .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_tooltips th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_after_tooltips th.col_heading {
#   text-align: center;
# }
# #T_after_tooltips th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_after_tooltips td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_after_tooltips th.col2 {
#   border-left: 1px solid white;
# }
# #T_after_tooltips td.col2 {
#   border-left: 1px solid #000066;
# }
# #T_after_tooltips .true {
#   background-color: #e6ffe6;
# }
# #T_after_tooltips .false {
#   background-color: #ffe6e6;
# }
# #T_after_tooltips caption {
#   caption-side: bottom;
#   font-size: 1.25em;
# }
# #T_after_tooltips .border-red {
#   border: 2px dashed red;
# }
# #T_after_tooltips .border-green {
#   border: 2px dashed green;
# }
# #T_after_tooltips .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   transform: translate(0px, -24px);
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_after_tooltips #T_after_tooltips_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_after_tooltips #T_after_tooltips_row0_col0 .pd-t::after {
#   content: "This model has a very strong true positive rate";
# }
# #T_after_tooltips #T_after_tooltips_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_after_tooltips #T_after_tooltips_row0_col3 .pd-t::after {
#   content: "This model's total number of false negatives is too high";
# }
# </style>
# <table id="T_after_tooltips" class="my-table-cls">
#   <caption>Confusion matrix for multiple cancer prediction models.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_tooltips_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_tooltips_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_tooltips_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_tooltips_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_tooltips_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_tooltips_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_tooltips_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_tooltips_row0_col0" class="data row0 col0 true border-green " >38<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row0_col1" class="data row0 col1 false  " >2<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row0_col2" class="data row0 col2 true  " >18<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row0_col3" class="data row0 col3 false border-red " >22<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_after_tooltips_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_tooltips_row1_col0" class="data row1 col0 false  " >19<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row1_col1" class="data row1 col1 true  " >439<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row1_col2" class="data row1 col2 false  " >6<span class="pd-t"></span></td>
#       <td id="T_after_tooltips_row1_col3" class="data row1 col3 true  " >452<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>

# %%
# Hidden cell to avoid CSS clashes and latter code upcoding previous formatting
s.set_uuid("after_borders")
# Out:
# <style type="text/css">
# #T_after_borders td:hover {
#   background-color: #ffffb3;
# }
# #T_after_borders .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_after_borders th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_after_borders th.col_heading {
#   text-align: center;
# }
# #T_after_borders th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_after_borders td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_after_borders th.col2 {
#   border-left: 1px solid white;
# }
# #T_after_borders td.col2 {
#   border-left: 1px solid #000066;
# }
# #T_after_borders .true {
#   background-color: #e6ffe6;
# }
# #T_after_borders .false {
#   background-color: #ffe6e6;
# }
# #T_after_borders caption {
#   caption-side: bottom;
#   font-size: 1.25em;
# }
# #T_after_borders .border-red {
#   border: 2px dashed red;
# }
# #T_after_borders .border-green {
#   border: 2px dashed green;
# }
# #T_after_borders .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   transform: translate(0px, -24px);
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_after_borders #T_after_borders_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_after_borders #T_after_borders_row0_col0 .pd-t::after {
#   content: "This model has a very strong true positive rate";
# }
# #T_after_borders #T_after_borders_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_after_borders #T_after_borders_row0_col3 .pd-t::after {
#   content: "This model's total number of false negatives is too high";
# }
# </style>
# <table id="T_after_borders" class="my-table-cls">
#   <caption>Confusion matrix for multiple cancer prediction models.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_after_borders_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_after_borders_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_after_borders_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_after_borders_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_after_borders_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_after_borders_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_after_borders_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_after_borders_row0_col0" class="data row0 col0 true border-green " >38<span class="pd-t"></span></td>
#       <td id="T_after_borders_row0_col1" class="data row0 col1 false  " >2<span class="pd-t"></span></td>
#       <td id="T_after_borders_row0_col2" class="data row0 col2 true  " >18<span class="pd-t"></span></td>
#       <td id="T_after_borders_row0_col3" class="data row0 col3 false border-red " >22<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_after_borders_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_after_borders_row1_col0" class="data row1 col0 false  " >19<span class="pd-t"></span></td>
#       <td id="T_after_borders_row1_col1" class="data row1 col1 true  " >439<span class="pd-t"></span></td>
#       <td id="T_after_borders_row1_col2" class="data row1 col2 false  " >6<span class="pd-t"></span></td>
#       <td id="T_after_borders_row1_col3" class="data row1 col3 true  " >452<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Finer Control with Slicing
#
# The examples we have shown so far for the `Styler.apply` and `Styler.map` functions have not demonstrated the use of the ``subset`` argument. This is a useful argument which permits a lot of flexibility: it allows you to apply styles to specific rows or columns, without having to code that logic into your `style` function.
#
# The value passed to `subset` behaves similar to slicing a DataFrame;
#
# - A scalar is treated as a column label
# - A list (or Series or NumPy array) is treated as multiple column labels
# - A tuple is treated as `(row_indexer, column_indexer)`
#
# Consider using `pd.IndexSlice` to construct the tuple for the last one. We will create a MultiIndexed DataFrame to demonstrate the functionality.

# %%
df3 = pd.DataFrame(
    np.random.default_rng().standard_normal((4, 4)),
    pd.MultiIndex.from_product([["A", "B"], ["r1", "r2"]]),
    columns=["c1", "c2", "c3", "c4"],
)
df3
# Out:
#             c1        c2        c3        c4
# A r1 -1.736200 -0.010202 -0.859117 -0.448975
#   r2  0.793431  0.391529  0.098790  1.104990
# B r1 -1.380188  0.552446  1.346542 -0.319337
#   r2 -0.100498 -1.365924  0.054814  0.012334

# %% [markdown]
# We will use subset to highlight the maximum in the third and fourth columns with red text. We will highlight the subset sliced region in yellow.

# %%
slice_ = ["c3", "c4"]
df3.style.apply(
    highlight_max, props="color:red;", axis=0, subset=slice_
).set_properties(**{"background-color": "#ffffb3"}, subset=slice_)
# Out:
# <style type="text/css">
# #T_4829a_row0_col2, #T_4829a_row0_col3, #T_4829a_row1_col2, #T_4829a_row2_col3, #T_4829a_row3_col2, #T_4829a_row3_col3 {
#   background-color: #ffffb3;
# }
# #T_4829a_row1_col3, #T_4829a_row2_col2 {
#   color: red;
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_4829a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4829a_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_4829a_level0_col1" class="col_heading level0 col1" >c2</th>
#       <th id="T_4829a_level0_col2" class="col_heading level0 col2" >c3</th>
#       <th id="T_4829a_level0_col3" class="col_heading level0 col3" >c4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4829a_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#       <th id="T_4829a_level1_row0" class="row_heading level1 row0" >r1</th>
#       <td id="T_4829a_row0_col0" class="data row0 col0" >-1.736200</td>
#       <td id="T_4829a_row0_col1" class="data row0 col1" >-0.010202</td>
#       <td id="T_4829a_row0_col2" class="data row0 col2" >-0.859117</td>
#       <td id="T_4829a_row0_col3" class="data row0 col3" >-0.448975</td>
#     </tr>
#     <tr>
#       <th id="T_4829a_level1_row1" class="row_heading level1 row1" >r2</th>
#       <td id="T_4829a_row1_col0" class="data row1 col0" >0.793431</td>
#       <td id="T_4829a_row1_col1" class="data row1 col1" >0.391529</td>
#       <td id="T_4829a_row1_col2" class="data row1 col2" >0.098790</td>
#       <td id="T_4829a_row1_col3" class="data row1 col3" >1.104990</td>
#     </tr>
#     <tr>
#       <th id="T_4829a_level0_row2" class="row_heading level0 row2" rowspan="2">B</th>
#       <th id="T_4829a_level1_row2" class="row_heading level1 row2" >r1</th>
#       <td id="T_4829a_row2_col0" class="data row2 col0" >-1.380188</td>
#       <td id="T_4829a_row2_col1" class="data row2 col1" >0.552446</td>
#       <td id="T_4829a_row2_col2" class="data row2 col2" >1.346542</td>
#       <td id="T_4829a_row2_col3" class="data row2 col3" >-0.319337</td>
#     </tr>
#     <tr>
#       <th id="T_4829a_level1_row3" class="row_heading level1 row3" >r2</th>
#       <td id="T_4829a_row3_col0" class="data row3 col0" >-0.100498</td>
#       <td id="T_4829a_row3_col1" class="data row3 col1" >-1.365924</td>
#       <td id="T_4829a_row3_col2" class="data row3 col2" >0.054814</td>
#       <td id="T_4829a_row3_col3" class="data row3 col3" >0.012334</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If combined with the ``IndexSlice`` as suggested then it can index across both dimensions with greater flexibility.

# %%
idx = pd.IndexSlice
slice_ = idx[idx[:, "r1"], idx["c2":"c4"]]
df3.style.apply(
    highlight_max, props="color:red;", axis=0, subset=slice_
).set_properties(**{"background-color": "#ffffb3"}, subset=slice_)
# Out:
# <style type="text/css">
# #T_d869b_row0_col1, #T_d869b_row0_col2, #T_d869b_row0_col3 {
#   background-color: #ffffb3;
# }
# #T_d869b_row2_col1, #T_d869b_row2_col2, #T_d869b_row2_col3 {
#   color: red;
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_d869b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d869b_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_d869b_level0_col1" class="col_heading level0 col1" >c2</th>
#       <th id="T_d869b_level0_col2" class="col_heading level0 col2" >c3</th>
#       <th id="T_d869b_level0_col3" class="col_heading level0 col3" >c4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d869b_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#       <th id="T_d869b_level1_row0" class="row_heading level1 row0" >r1</th>
#       <td id="T_d869b_row0_col0" class="data row0 col0" >-1.736200</td>
#       <td id="T_d869b_row0_col1" class="data row0 col1" >-0.010202</td>
#       <td id="T_d869b_row0_col2" class="data row0 col2" >-0.859117</td>
#       <td id="T_d869b_row0_col3" class="data row0 col3" >-0.448975</td>
#     </tr>
#     <tr>
#       <th id="T_d869b_level1_row1" class="row_heading level1 row1" >r2</th>
#       <td id="T_d869b_row1_col0" class="data row1 col0" >0.793431</td>
#       <td id="T_d869b_row1_col1" class="data row1 col1" >0.391529</td>
#       <td id="T_d869b_row1_col2" class="data row1 col2" >0.098790</td>
#       <td id="T_d869b_row1_col3" class="data row1 col3" >1.104990</td>
#     </tr>
#     <tr>
#       <th id="T_d869b_level0_row2" class="row_heading level0 row2" rowspan="2">B</th>
#       <th id="T_d869b_level1_row2" class="row_heading level1 row2" >r1</th>
#       <td id="T_d869b_row2_col0" class="data row2 col0" >-1.380188</td>
#       <td id="T_d869b_row2_col1" class="data row2 col1" >0.552446</td>
#       <td id="T_d869b_row2_col2" class="data row2 col2" >1.346542</td>
#       <td id="T_d869b_row2_col3" class="data row2 col3" >-0.319337</td>
#     </tr>
#     <tr>
#       <th id="T_d869b_level1_row3" class="row_heading level1 row3" >r2</th>
#       <td id="T_d869b_row3_col0" class="data row3 col0" >-0.100498</td>
#       <td id="T_d869b_row3_col1" class="data row3 col1" >-1.365924</td>
#       <td id="T_d869b_row3_col2" class="data row3 col2" >0.054814</td>
#       <td id="T_d869b_row3_col3" class="data row3 col3" >0.012334</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This also provides the flexibility to sub select rows when used with the `axis=1`.

# %%
slice_ = idx[idx[:, "r2"], :]
df3.style.apply(
    highlight_max, props="color:red;", axis=1, subset=slice_
).set_properties(**{"background-color": "#ffffb3"}, subset=slice_)
# Out:
# <style type="text/css">
# #T_eb875_row1_col0, #T_eb875_row1_col1, #T_eb875_row1_col2, #T_eb875_row3_col0, #T_eb875_row3_col1, #T_eb875_row3_col3 {
#   background-color: #ffffb3;
# }
# #T_eb875_row1_col3, #T_eb875_row3_col2 {
#   color: red;
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_eb875">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb875_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_eb875_level0_col1" class="col_heading level0 col1" >c2</th>
#       <th id="T_eb875_level0_col2" class="col_heading level0 col2" >c3</th>
#       <th id="T_eb875_level0_col3" class="col_heading level0 col3" >c4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb875_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#       <th id="T_eb875_level1_row0" class="row_heading level1 row0" >r1</th>
#       <td id="T_eb875_row0_col0" class="data row0 col0" >-1.736200</td>
#       <td id="T_eb875_row0_col1" class="data row0 col1" >-0.010202</td>
#       <td id="T_eb875_row0_col2" class="data row0 col2" >-0.859117</td>
#       <td id="T_eb875_row0_col3" class="data row0 col3" >-0.448975</td>
#     </tr>
#     <tr>
#       <th id="T_eb875_level1_row1" class="row_heading level1 row1" >r2</th>
#       <td id="T_eb875_row1_col0" class="data row1 col0" >0.793431</td>
#       <td id="T_eb875_row1_col1" class="data row1 col1" >0.391529</td>
#       <td id="T_eb875_row1_col2" class="data row1 col2" >0.098790</td>
#       <td id="T_eb875_row1_col3" class="data row1 col3" >1.104990</td>
#     </tr>
#     <tr>
#       <th id="T_eb875_level0_row2" class="row_heading level0 row2" rowspan="2">B</th>
#       <th id="T_eb875_level1_row2" class="row_heading level1 row2" >r1</th>
#       <td id="T_eb875_row2_col0" class="data row2 col0" >-1.380188</td>
#       <td id="T_eb875_row2_col1" class="data row2 col1" >0.552446</td>
#       <td id="T_eb875_row2_col2" class="data row2 col2" >1.346542</td>
#       <td id="T_eb875_row2_col3" class="data row2 col3" >-0.319337</td>
#     </tr>
#     <tr>
#       <th id="T_eb875_level1_row3" class="row_heading level1 row3" >r2</th>
#       <td id="T_eb875_row3_col0" class="data row3 col0" >-0.100498</td>
#       <td id="T_eb875_row3_col1" class="data row3 col1" >-1.365924</td>
#       <td id="T_eb875_row3_col2" class="data row3 col2" >0.054814</td>
#       <td id="T_eb875_row3_col3" class="data row3 col3" >0.012334</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There is also scope to provide **conditional filtering**.
#
# Suppose we want to highlight the maximum across columns 2 and 4 only in the case that the sum of columns 1 and 3 is less than -2.0 *(essentially excluding rows* `(:,'r2')`*)*.

# %%
slice_ = idx[idx[(df3["c1"] + df3["c3"]) < -2.0], ["c2", "c4"]]
df3.style.apply(
    highlight_max, props="color:red;", axis=1, subset=slice_
).set_properties(**{"background-color": "#ffffb3"}, subset=slice_)
# Out:
# <style type="text/css">
# #T_138e2_row0_col1 {
#   color: red;
#   background-color: #ffffb3;
# }
# #T_138e2_row0_col3 {
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_138e2">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_138e2_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_138e2_level0_col1" class="col_heading level0 col1" >c2</th>
#       <th id="T_138e2_level0_col2" class="col_heading level0 col2" >c3</th>
#       <th id="T_138e2_level0_col3" class="col_heading level0 col3" >c4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_138e2_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#       <th id="T_138e2_level1_row0" class="row_heading level1 row0" >r1</th>
#       <td id="T_138e2_row0_col0" class="data row0 col0" >-1.736200</td>
#       <td id="T_138e2_row0_col1" class="data row0 col1" >-0.010202</td>
#       <td id="T_138e2_row0_col2" class="data row0 col2" >-0.859117</td>
#       <td id="T_138e2_row0_col3" class="data row0 col3" >-0.448975</td>
#     </tr>
#     <tr>
#       <th id="T_138e2_level1_row1" class="row_heading level1 row1" >r2</th>
#       <td id="T_138e2_row1_col0" class="data row1 col0" >0.793431</td>
#       <td id="T_138e2_row1_col1" class="data row1 col1" >0.391529</td>
#       <td id="T_138e2_row1_col2" class="data row1 col2" >0.098790</td>
#       <td id="T_138e2_row1_col3" class="data row1 col3" >1.104990</td>
#     </tr>
#     <tr>
#       <th id="T_138e2_level0_row2" class="row_heading level0 row2" rowspan="2">B</th>
#       <th id="T_138e2_level1_row2" class="row_heading level1 row2" >r1</th>
#       <td id="T_138e2_row2_col0" class="data row2 col0" >-1.380188</td>
#       <td id="T_138e2_row2_col1" class="data row2 col1" >0.552446</td>
#       <td id="T_138e2_row2_col2" class="data row2 col2" >1.346542</td>
#       <td id="T_138e2_row2_col3" class="data row2 col3" >-0.319337</td>
#     </tr>
#     <tr>
#       <th id="T_138e2_level1_row3" class="row_heading level1 row3" >r2</th>
#       <td id="T_138e2_row3_col0" class="data row3 col0" >-0.100498</td>
#       <td id="T_138e2_row3_col1" class="data row3 col1" >-1.365924</td>
#       <td id="T_138e2_row3_col2" class="data row3 col2" >0.054814</td>
#       <td id="T_138e2_row3_col3" class="data row3 col3" >0.012334</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Only label-based slicing is supported right now, not positional, and not callables.
#
# If your style function uses a `subset` or `axis` keyword argument, consider wrapping your function in a `functools.partial`, partialing out that keyword.
#
# ```python
# my_func2 = functools.partial(my_func, subset=42)
# ```

# %% [markdown]
# ## Optimization
#
# Generally, for smaller tables and most cases, the rendered HTML does not need to be optimized, and we don't really recommend it. There are two cases where it is worth considering:
#
#  - If you are rendering and styling a very large HTML table, certain browsers have performance issues.
#  - If you are using ``Styler`` to dynamically create part of online user interfaces and want to improve network performance.
#
# Here we recommend the following steps to implement:

# %% [markdown]
# ### 1. Remove UUID and cell_ids
#
# Ignore the `uuid` and set `cell_ids` to `False`. This will prevent unnecessary HTML.

# %% [markdown]
# <div class="alert alert-warning">
#
# <font color=red>This is sub-optimal:</font>
#
# </div>

# %%
df4 = pd.DataFrame([[1, 2], [3, 4]])
s4 = df4.style

# %% [markdown]
# <div class="alert alert-info">
#
# <font color=green>This is better:</font>
#
# </div>

# %%
from pandas.io.formats.style import Styler

s4 = Styler(df4, uuid_len=0, cell_ids=False)

# %% [markdown]
# ### 2. Use table styles
#
# Use table styles where possible (e.g. for all cells or rows or columns at a time) since the CSS is nearly always more efficient than other formats.

# %% [markdown]
# <div class="alert alert-warning">
#
# <font color=red>This is sub-optimal:</font>
#
# </div>

# %%
props = 'font-family: "Times New Roman", Times, serif; color: #e83e8c; font-size:1.3em;'
df4.style.map(lambda x: props, subset=[1])
# Out:
# <style type="text/css">
# #T_3e836_row0_col1, #T_3e836_row1_col1 {
#   font-family: "Times New Roman", Times, serif;
#   color: #e83e8c;
#   font-size: 1.3em;
# }
# </style>
# <table id="T_3e836">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e836_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3e836_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e836_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e836_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3e836_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3e836_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3e836_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_3e836_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-info">
#
# <font color=green>This is better:</font>
#
# </div>

# %%
df4.style.set_table_styles([{"selector": "td.col1", "props": props}])
# Out:
# <style type="text/css">
# #T_e70c5 td.col1 {
#   font-family: "Times New Roman", Times, serif;
#   color: #e83e8c;
#   font-size: 1.3em;
# }
# </style>
# <table id="T_e70c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e70c5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e70c5_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e70c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e70c5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e70c5_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e70c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e70c5_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_e70c5_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3. Set classes instead of using Styler functions
#
# For large DataFrames where the same style is applied to many cells it can be more efficient to declare the styles as classes and then apply those classes to data cells, rather than directly applying styles to cells. It is, however, probably still easier to use the Styler function api when you are not concerned about optimization.

# %% [markdown]
# <div class="alert alert-warning">
#
# <font color=red>This is sub-optimal:</font>
#
# </div>

# %%
df2.style.apply(
    highlight_max, props="color:white;background-color:darkblue;", axis=0
).apply(highlight_max, props="color:white;background-color:pink;", axis=1).apply(
    highlight_max, props="color:white;background-color:purple", axis=None
)
# Out:
# <style type="text/css">
# #T_8dce7_row0_col2, #T_8dce7_row2_col3, #T_8dce7_row3_col1, #T_8dce7_row4_col3, #T_8dce7_row7_col1, #T_8dce7_row8_col1 {
#   color: white;
#   background-color: pink;
# }
# #T_8dce7_row1_col2, #T_8dce7_row5_col1, #T_8dce7_row6_col0 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
# }
# #T_8dce7_row9_col3 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
# }
# </style>
# <table id="T_8dce7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dce7_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8dce7_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_8dce7_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_8dce7_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dce7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8dce7_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_8dce7_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_8dce7_row0_col2" class="data row0 col2" >0.640423</td>
#       <td id="T_8dce7_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_8dce7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8dce7_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_8dce7_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_8dce7_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_8dce7_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_8dce7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8dce7_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_8dce7_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_8dce7_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_8dce7_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_8dce7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8dce7_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_8dce7_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_8dce7_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_8dce7_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_8dce7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8dce7_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_8dce7_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_8dce7_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_8dce7_row4_col3" class="data row4 col3" >1.042513</td>
#     </tr>
#     <tr>
#       <th id="T_8dce7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8dce7_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_8dce7_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_8dce7_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_8dce7_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_8dce7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8dce7_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_8dce7_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_8dce7_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_8dce7_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_8dce7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8dce7_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_8dce7_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_8dce7_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_8dce7_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_8dce7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8dce7_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_8dce7_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_8dce7_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_8dce7_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_8dce7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8dce7_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_8dce7_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_8dce7_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_8dce7_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-info">
#
# <font color=green>This is better:</font>
#
# </div>

# %%
build = lambda x: pd.DataFrame(x, index=df2.index, columns=df2.columns)
cls1 = build(df2.apply(highlight_max, props="cls-1 ", axis=0))
cls2 = build(
    df2.apply(highlight_max, props="cls-2 ", axis=1, result_type="expand").values
)
cls3 = build(highlight_max(df2, props="cls-3 "))
df2.style.set_table_styles(
    [
        {"selector": ".cls-1", "props": "color:white;background-color:darkblue;"},
        {"selector": ".cls-2", "props": "color:white;background-color:pink;"},
        {"selector": ".cls-3", "props": "color:white;background-color:purple;"},
    ]
).set_td_classes(cls1 + cls2 + cls3)
# Out:
# <style type="text/css">
# #T_bbb5d .cls-1 {
#   color: white;
#   background-color: darkblue;
# }
# #T_bbb5d .cls-2 {
#   color: white;
#   background-color: pink;
# }
# #T_bbb5d .cls-3 {
#   color: white;
#   background-color: purple;
# }
# </style>
# <table id="T_bbb5d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbb5d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_bbb5d_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_bbb5d_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_bbb5d_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbb5d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bbb5d_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_bbb5d_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_bbb5d_row0_col2" class="data row0 col2 cls-2 " >0.640423</td>
#       <td id="T_bbb5d_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_bbb5d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bbb5d_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_bbb5d_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_bbb5d_row1_col2" class="data row1 col2 cls-1 cls-2 " >1.304000</td>
#       <td id="T_bbb5d_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_bbb5d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bbb5d_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_bbb5d_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_bbb5d_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_bbb5d_row2_col3" class="data row2 col3 cls-2 " >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_bbb5d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bbb5d_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_bbb5d_row3_col1" class="data row3 col1 cls-2 " >-0.218792</td>
#       <td id="T_bbb5d_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_bbb5d_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_bbb5d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bbb5d_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_bbb5d_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_bbb5d_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_bbb5d_row4_col3" class="data row4 col3 cls-2 " >1.042513</td>
#     </tr>
#     <tr>
#       <th id="T_bbb5d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bbb5d_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_bbb5d_row5_col1" class="data row5 col1 cls-1 cls-2 " >1.366463</td>
#       <td id="T_bbb5d_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_bbb5d_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_bbb5d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bbb5d_row6_col0" class="data row6 col0 cls-1 cls-2 " >0.903470</td>
#       <td id="T_bbb5d_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_bbb5d_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_bbb5d_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_bbb5d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bbb5d_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_bbb5d_row7_col1" class="data row7 col1 cls-2 " >0.220195</td>
#       <td id="T_bbb5d_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_bbb5d_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_bbb5d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bbb5d_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_bbb5d_row8_col1" class="data row8 col1 cls-2 " >0.540846</td>
#       <td id="T_bbb5d_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_bbb5d_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_bbb5d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bbb5d_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_bbb5d_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_bbb5d_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_bbb5d_row9_col3" class="data row9 col3 cls-1 cls-2 cls-3 " >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4. Don't use tooltips
#
# Tooltips require `cell_ids` to work and they generate extra HTML elements for *every* data cell.

# %% [markdown]
# ### 5. If every byte counts use string replacement
#
# You can remove unnecessary HTML, or shorten the default class names by replacing the default css dict. You can read a little more about CSS [below](#More-About-CSS-and-HTML).

# %%
my_css = {
    "row_heading": "",
    "col_heading": "",
    "index_name": "",
    "col": "c",
    "row": "r",
    "col_trim": "",
    "row_trim": "",
    "level": "l",
    "data": "",
    "blank": "",
}
html = Styler(df4, uuid_len=0, cell_ids=False)
html.set_table_styles(
    [
        {"selector": "td", "props": props},
        {"selector": ".c1", "props": "color:green;"},
        {"selector": ".l0", "props": "color:blue;"},
    ],
    css_class_names=my_css,
)
print(html.to_html())
# Out:
# <style type="text/css">
# #T_ td {
#   font-family: "Times New Roman", Times, serif;
#   color: #e83e8c;
#   font-size: 1.3em;
# }
# #T_ .c1 {
#   color: green;
# }
# #T_ .l0 {
#   color: blue;
# }
# </style>
# <table id="T_">
#   <thead>
#     <tr>
#       <th class=" l0" >&nbsp;</th>
#       <th class=" l0 c0" >0</th>
#       <th class=" l0 c1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th class=" l0 r0" >0</th>
#       <td class=" r0 c0" >1</td>
#       <td class=" r0 c1" >2</td>
#     </tr>
#     <tr>
#       <th class=" l0 r1" >1</th>
#       <td class=" r1 c0" >3</td>
#       <td class=" r1 c1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
html
# Out:
# <style type="text/css">
# #T_ td {
#   font-family: "Times New Roman", Times, serif;
#   color: #e83e8c;
#   font-size: 1.3em;
# }
# #T_ .c1 {
#   color: green;
# }
# #T_ .l0 {
#   color: blue;
# }
# </style>
# <table id="T_">
#   <thead>
#     <tr>
#       <th class=" l0" >&nbsp;</th>
#       <th class=" l0 c0" >0</th>
#       <th class=" l0 c1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th class=" l0 r0" >0</th>
#       <td class=" r0 c0" >1</td>
#       <td class=" r0 c1" >2</td>
#     </tr>
#     <tr>
#       <th class=" l0 r1" >1</th>
#       <td class=" r1 c0" >3</td>
#       <td class=" r1 c1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Builtin Styles

# %% [markdown]
# Some styling functions are common enough that we've "built them in" to the `Styler`, so you don't have to write them and apply them yourself. The current list of such functions is:
#
#  - [.highlight_null][nullfunc]: for use with identifying missing data.
#  - [.highlight_min][minfunc] and [.highlight_max][maxfunc]: for use with identifying extremities in data.
#  - [.highlight_between][betweenfunc] and [.highlight_quantile][quantilefunc]: for use with identifying classes within data.
#  - [.background_gradient][bgfunc]: a flexible method for highlighting cells based on their, or other, values on a numeric scale.
#  - [.text_gradient][textfunc]: similar method for highlighting text based on their, or other, values on a numeric scale.
#  - [.bar][barfunc]: to display mini-charts within cell backgrounds.
#
# The individual documentation on each function often gives more examples of their arguments.
#
# [nullfunc]: ../reference/api/pandas.io.formats.style.Styler.highlight_null.rst
# [minfunc]: ../reference/api/pandas.io.formats.style.Styler.highlight_min.rst
# [maxfunc]: ../reference/api/pandas.io.formats.style.Styler.highlight_max.rst
# [betweenfunc]: ../reference/api/pandas.io.formats.style.Styler.highlight_between.rst
# [quantilefunc]: ../reference/api/pandas.io.formats.style.Styler.highlight_quantile.rst
# [bgfunc]: ../reference/api/pandas.io.formats.style.Styler.background_gradient.rst
# [textfunc]: ../reference/api/pandas.io.formats.style.Styler.text_gradient.rst
# [barfunc]: ../reference/api/pandas.io.formats.style.Styler.bar.rst

# %% [markdown]
# ### Highlight Null

# %%
df2.iloc[0, 2] = np.nan
df2.iloc[4, 3] = np.nan
df2.loc[:4].style.highlight_null(color="yellow")
# Out:
# <style type="text/css">
# #T_f3b37_row0_col2, #T_f3b37_row4_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f3b37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3b37_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f3b37_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_f3b37_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_f3b37_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3b37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3b37_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_f3b37_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_f3b37_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_f3b37_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_f3b37_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3b37_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_f3b37_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_f3b37_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_f3b37_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_f3b37_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3b37_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_f3b37_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_f3b37_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_f3b37_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_f3b37_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3b37_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_f3b37_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_f3b37_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_f3b37_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_f3b37_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3b37_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_f3b37_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_f3b37_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_f3b37_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Highlight Min or Max

# %%
df2.loc[:4].style.highlight_max(
    axis=1, props=("color:white; font-weight:bold; background-color:darkblue;")
)
# Out:
# <style type="text/css">
# #T_59f81_row0_col0, #T_59f81_row1_col2, #T_59f81_row2_col3, #T_59f81_row3_col1, #T_59f81_row4_col2 {
#   color: white;
#   font-weight: bold;
#   background-color: darkblue;
# }
# </style>
# <table id="T_59f81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59f81_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_59f81_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_59f81_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_59f81_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59f81_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59f81_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_59f81_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_59f81_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_59f81_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_59f81_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59f81_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_59f81_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_59f81_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_59f81_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_59f81_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_59f81_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_59f81_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_59f81_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_59f81_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_59f81_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_59f81_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_59f81_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_59f81_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_59f81_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_59f81_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_59f81_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_59f81_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_59f81_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_59f81_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Highlight Between
# This method accepts ranges as float, or NumPy arrays or Series provided the indexes match.

# %%
left = pd.Series([1.0, 0.0, 1.0], index=["A", "B", "D"])
df2.loc[:4].style.highlight_between(
    left=left, right=1.5, axis=1, props="color:white; background-color:purple;"
)
# Out:
# <style type="text/css">
# #T_f356c_row1_col1 {
#   color: white;
#   background-color: purple;
# }
# </style>
# <table id="T_f356c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f356c_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f356c_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_f356c_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_f356c_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f356c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f356c_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_f356c_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_f356c_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_f356c_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_f356c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f356c_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_f356c_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_f356c_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_f356c_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_f356c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f356c_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_f356c_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_f356c_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_f356c_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_f356c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f356c_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_f356c_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_f356c_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_f356c_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_f356c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f356c_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_f356c_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_f356c_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_f356c_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Highlight Quantile
# Useful for detecting the highest or lowest percentile values

# %%
df2.loc[:4].style.highlight_quantile(q_left=0.85, axis=None, color="yellow")
# Out:
# <style type="text/css">
# #T_b9bac_row1_col2, #T_b9bac_row1_col3, #T_b9bac_row4_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b9bac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9bac_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b9bac_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b9bac_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b9bac_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9bac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9bac_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_b9bac_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_b9bac_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_b9bac_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_b9bac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9bac_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_b9bac_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_b9bac_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_b9bac_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_b9bac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9bac_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_b9bac_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_b9bac_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_b9bac_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_b9bac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9bac_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_b9bac_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_b9bac_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_b9bac_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_b9bac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9bac_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_b9bac_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_b9bac_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_b9bac_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Background Gradient and Text Gradient

# %% [markdown]
# You can create "heatmaps" with the `background_gradient` and `text_gradient` methods. These require matplotlib, and we'll use [Seaborn](https://seaborn.pydata.org/) to get a nice colormap.

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)

df2.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_8ead5_row0_col0 {
#   background-color: #389b38;
#   color: #f1f1f1;
# }
# #T_8ead5_row0_col1, #T_8ead5_row9_col1 {
#   background-color: #85c185;
#   color: #000000;
# }
# #T_8ead5_row0_col2, #T_8ead5_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_8ead5_row0_col3 {
#   background-color: #87c287;
#   color: #000000;
# }
# #T_8ead5_row1_col0, #T_8ead5_row4_col0 {
#   background-color: #69b369;
#   color: #f1f1f1;
# }
# #T_8ead5_row1_col1 {
#   background-color: #59ac59;
#   color: #f1f1f1;
# }
# #T_8ead5_row1_col2, #T_8ead5_row5_col1, #T_8ead5_row6_col0, #T_8ead5_row9_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_8ead5_row1_col3 {
#   background-color: #349a34;
#   color: #f1f1f1;
# }
# #T_8ead5_row2_col0 {
#   background-color: #75b975;
#   color: #f1f1f1;
# }
# #T_8ead5_row2_col1, #T_8ead5_row3_col0, #T_8ead5_row3_col2, #T_8ead5_row6_col3 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_8ead5_row2_col2 {
#   background-color: #b2d7b1;
#   color: #000000;
# }
# #T_8ead5_row2_col3 {
#   background-color: #8dc58d;
#   color: #000000;
# }
# #T_8ead5_row3_col1 {
#   background-color: #8ec58e;
#   color: #000000;
# }
# #T_8ead5_row3_col3 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_8ead5_row4_col1 {
#   background-color: #96c996;
#   color: #000000;
# }
# #T_8ead5_row4_col2 {
#   background-color: #52a852;
#   color: #f1f1f1;
# }
# #T_8ead5_row5_col0 {
#   background-color: #4ba54a;
#   color: #f1f1f1;
# }
# #T_8ead5_row5_col2 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_8ead5_row5_col3 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_8ead5_row6_col1, #T_8ead5_row9_col0 {
#   background-color: #71b771;
#   color: #f1f1f1;
# }
# #T_8ead5_row6_col2 {
#   background-color: #bddcbd;
#   color: #000000;
# }
# #T_8ead5_row7_col0 {
#   background-color: #62b062;
#   color: #f1f1f1;
# }
# #T_8ead5_row7_col1 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_8ead5_row7_col2 {
#   background-color: #d5e9d5;
#   color: #000000;
# }
# #T_8ead5_row7_col3 {
#   background-color: #a6d1a6;
#   color: #000000;
# }
# #T_8ead5_row8_col0 {
#   background-color: #4da64d;
#   color: #f1f1f1;
# }
# #T_8ead5_row8_col1 {
#   background-color: #4aa44a;
#   color: #f1f1f1;
# }
# #T_8ead5_row8_col2 {
#   background-color: #64b164;
#   color: #f1f1f1;
# }
# #T_8ead5_row8_col3 {
#   background-color: #6eb66e;
#   color: #f1f1f1;
# }
# #T_8ead5_row9_col2 {
#   background-color: #309730;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8ead5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ead5_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8ead5_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_8ead5_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_8ead5_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ead5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ead5_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_8ead5_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_8ead5_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_8ead5_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_8ead5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8ead5_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_8ead5_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_8ead5_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_8ead5_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_8ead5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8ead5_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_8ead5_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_8ead5_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_8ead5_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_8ead5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8ead5_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_8ead5_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_8ead5_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_8ead5_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_8ead5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8ead5_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_8ead5_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_8ead5_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_8ead5_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8ead5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8ead5_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_8ead5_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_8ead5_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_8ead5_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_8ead5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8ead5_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_8ead5_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_8ead5_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_8ead5_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_8ead5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8ead5_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_8ead5_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_8ead5_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_8ead5_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_8ead5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8ead5_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_8ead5_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_8ead5_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_8ead5_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_8ead5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8ead5_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_8ead5_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_8ead5_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_8ead5_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %%
df2.style.text_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_89c88_row0_col0 {
#   color: #389b38;
# }
# #T_89c88_row0_col1, #T_89c88_row9_col1 {
#   color: #85c185;
# }
# #T_89c88_row0_col2, #T_89c88_row4_col3 {
#   color: #000000;
# }
# #T_89c88_row0_col3 {
#   color: #87c287;
# }
# #T_89c88_row1_col0, #T_89c88_row4_col0 {
#   color: #69b369;
# }
# #T_89c88_row1_col1 {
#   color: #59ac59;
# }
# #T_89c88_row1_col2, #T_89c88_row5_col1, #T_89c88_row6_col0, #T_89c88_row9_col3 {
#   color: #008000;
# }
# #T_89c88_row1_col3 {
#   color: #349a34;
# }
# #T_89c88_row2_col0 {
#   color: #75b975;
# }
# #T_89c88_row2_col1, #T_89c88_row3_col0, #T_89c88_row3_col2, #T_89c88_row6_col3 {
#   color: #ebf3eb;
# }
# #T_89c88_row2_col2 {
#   color: #b2d7b1;
# }
# #T_89c88_row2_col3 {
#   color: #8dc58d;
# }
# #T_89c88_row3_col1 {
#   color: #8ec58e;
# }
# #T_89c88_row3_col3 {
#   color: #d8ead8;
# }
# #T_89c88_row4_col1 {
#   color: #96c996;
# }
# #T_89c88_row4_col2 {
#   color: #52a852;
# }
# #T_89c88_row5_col0 {
#   color: #4ba54a;
# }
# #T_89c88_row5_col2 {
#   color: #b5d9b5;
# }
# #T_89c88_row5_col3 {
#   color: #6fb76f;
# }
# #T_89c88_row6_col1, #T_89c88_row9_col0 {
#   color: #71b771;
# }
# #T_89c88_row6_col2 {
#   color: #bddcbd;
# }
# #T_89c88_row7_col0 {
#   color: #62b062;
# }
# #T_89c88_row7_col1 {
#   color: #66b266;
# }
# #T_89c88_row7_col2 {
#   color: #d5e9d5;
# }
# #T_89c88_row7_col3 {
#   color: #a6d1a6;
# }
# #T_89c88_row8_col0 {
#   color: #4da64d;
# }
# #T_89c88_row8_col1 {
#   color: #4aa44a;
# }
# #T_89c88_row8_col2 {
#   color: #64b164;
# }
# #T_89c88_row8_col3 {
#   color: #6eb66e;
# }
# #T_89c88_row9_col2 {
#   color: #309730;
# }
# </style>
# <table id="T_89c88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89c88_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_89c88_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_89c88_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_89c88_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89c88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89c88_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_89c88_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_89c88_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_89c88_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_89c88_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_89c88_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_89c88_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_89c88_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_89c88_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_89c88_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_89c88_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_89c88_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_89c88_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_89c88_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_89c88_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_89c88_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_89c88_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_89c88_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_89c88_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_89c88_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_89c88_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_89c88_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_89c88_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_89c88_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_89c88_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_89c88_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_89c88_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_89c88_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_89c88_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_89c88_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_89c88_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_89c88_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_89c88_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_89c88_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_89c88_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_89c88_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_89c88_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_89c88_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_89c88_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_89c88_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_89c88_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_89c88_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_89c88_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_89c88_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_89c88_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_89c88_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_89c88_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_89c88_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_89c88_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# [.background_gradient][bgfunc] and [.text_gradient][textfunc] have a number of keyword arguments to customise the gradients and colors. See the documentation.
#
# [bgfunc]: ../reference/api/pandas.io.formats.style.Styler.background_gradient.rst
# [textfunc]: ../reference/api/pandas.io.formats.style.Styler.text_gradient.rst

# %% [markdown]
# ### Set properties
#
# Use `Styler.set_properties` when the style doesn't actually depend on the values. This is just a simple wrapper for `.map` where the function returns the same properties for all cells.

# %%
df2.loc[:4].style.set_properties(
    **{"background-color": "black", "color": "lawngreen", "border-color": "white"}
)
# Out:
# <style type="text/css">
# #T_0c4aa_row0_col0, #T_0c4aa_row0_col1, #T_0c4aa_row0_col2, #T_0c4aa_row0_col3, #T_0c4aa_row1_col0, #T_0c4aa_row1_col1, #T_0c4aa_row1_col2, #T_0c4aa_row1_col3, #T_0c4aa_row2_col0, #T_0c4aa_row2_col1, #T_0c4aa_row2_col2, #T_0c4aa_row2_col3, #T_0c4aa_row3_col0, #T_0c4aa_row3_col1, #T_0c4aa_row3_col2, #T_0c4aa_row3_col3, #T_0c4aa_row4_col0, #T_0c4aa_row4_col1, #T_0c4aa_row4_col2, #T_0c4aa_row4_col3 {
#   background-color: black;
#   color: lawngreen;
#   border-color: white;
# }
# </style>
# <table id="T_0c4aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c4aa_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0c4aa_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_0c4aa_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_0c4aa_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c4aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c4aa_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_0c4aa_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_0c4aa_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_0c4aa_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_0c4aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c4aa_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_0c4aa_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_0c4aa_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_0c4aa_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_0c4aa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c4aa_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_0c4aa_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_0c4aa_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_0c4aa_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_0c4aa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c4aa_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_0c4aa_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_0c4aa_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_0c4aa_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_0c4aa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c4aa_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_0c4aa_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_0c4aa_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_0c4aa_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Bar charts

# %% [markdown]
# You can include "bar charts" in your DataFrame.

# %%
df2.style.bar(subset=["A", "B"], color="#d65f5f")
# Out:
# <style type="text/css">
# #T_cb694_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 72.0%, #d65f5f 72.0%, #d65f5f 75.9%, transparent 75.9%);
# }
# #T_cb694_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 48.1%, transparent 48.1%);
# }
# #T_cb694_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 55.4%, #d65f5f 55.4%, #d65f5f 72.0%, transparent 72.0%);
# }
# #T_cb694_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.1%, #d65f5f 48.1%, #d65f5f 61.8%, transparent 61.8%);
# }
# #T_cb694_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.2%, #d65f5f 50.2%, #d65f5f 72.0%, transparent 72.0%);
# }
# #T_cb694_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.1%, transparent 48.1%);
# }
# #T_cb694_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 72.0%, transparent 72.0%);
# }
# #T_cb694_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.8%, #d65f5f 39.8%, #d65f5f 48.1%, transparent 48.1%);
# }
# #T_cb694_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 55.2%, #d65f5f 55.2%, #d65f5f 72.0%, transparent 72.0%);
# }
# #T_cb694_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.1%, #d65f5f 36.1%, #d65f5f 48.1%, transparent 48.1%);
# }
# #T_cb694_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 68.0%, #d65f5f 68.0%, #d65f5f 72.0%, transparent 72.0%);
# }
# #T_cb694_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.1%, #d65f5f 48.1%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_cb694_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 72.0%, #d65f5f 72.0%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_cb694_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.1%, #d65f5f 48.1%, #d65f5f 51.7%, transparent 51.7%);
# }
# #T_cb694_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 57.8%, #d65f5f 57.8%, #d65f5f 72.0%, transparent 72.0%);
# }
# #T_cb694_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.1%, #d65f5f 48.1%, #d65f5f 56.4%, transparent 56.4%);
# }
# #T_cb694_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 67.1%, #d65f5f 67.1%, #d65f5f 72.0%, transparent 72.0%);
# }
# #T_cb694_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.1%, #d65f5f 48.1%, #d65f5f 68.6%, transparent 68.6%);
# }
# #T_cb694_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 51.8%, #d65f5f 51.8%, #d65f5f 72.0%, transparent 72.0%);
# }
# #T_cb694_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.2%, #d65f5f 43.2%, #d65f5f 48.1%, transparent 48.1%);
# }
# </style>
# <table id="T_cb694">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb694_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_cb694_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_cb694_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_cb694_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb694_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb694_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_cb694_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_cb694_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_cb694_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb694_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_cb694_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_cb694_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_cb694_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb694_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_cb694_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_cb694_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_cb694_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb694_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_cb694_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_cb694_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_cb694_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb694_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_cb694_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_cb694_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_cb694_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb694_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_cb694_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_cb694_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_cb694_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb694_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_cb694_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_cb694_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_cb694_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cb694_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_cb694_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_cb694_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_cb694_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cb694_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_cb694_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_cb694_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_cb694_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cb694_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_cb694_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_cb694_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_cb694_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Additional keyword arguments give more control on centering and positioning, and you can pass a list of `[color_negative, color_positive]` to highlight lower and higher values or a matplotlib colormap.
#
# To showcase an example here's how you can change the above with the new `align` option, combined with setting `vmin` and `vmax` limits, the `width` of the figure, and underlying css `props` of cells, leaving space to display the text and the bars. We also use `text_gradient` to color the text the same as the bars using a matplotlib colormap (although in this case the visualization is probably better without this additional effect).

# %%
df2.style.format("{:.3f}", na_rep="").bar(
    align=0,
    vmin=-2.5,
    vmax=2.5,
    cmap="bwr",
    height=50,
    width=60,
    props="width: 120px; border-right: 1px solid black;",
).text_gradient(cmap="bwr", vmin=-2.5, vmax=2.5)
# Out:
# <style type="text/css">
# #T_2a090_row0_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fff2f2 30.0%, #fff2f2 31.5%, transparent 31.5%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #fff2f2;
# }
# #T_2a090_row0_col1, #T_2a090_row9_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 28.4%, #f2f2ff 28.4%, #f2f2ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #f2f2ff;
# }
# #T_2a090_row0_col2, #T_2a090_row4_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   color: #000000;
# }
# #T_2a090_row0_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fff4f4 30.0%, #fff4f4 31.3%, transparent 31.3%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #fff4f4;
# }
# #T_2a090_row1_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 23.6%, #c8c8ff 23.6%, #c8c8ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #c8c8ff;
# }
# #T_2a090_row1_col1, #T_2a090_row8_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ffdada 30.0%, #ffdada 34.3%, transparent 34.3%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ffdada;
# }
# #T_2a090_row1_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ff7a7a 30.0%, #ff7a7a 45.6%, transparent 45.6%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ff7a7a;
# }
# #T_2a090_row1_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ff9e9e 30.0%, #ff9e9e 41.4%, transparent 41.4%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ff9e9e;
# }
# #T_2a090_row2_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 21.6%, #b6b6ff 21.6%, #b6b6ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #b6b6ff;
# }
# #T_2a090_row2_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 14.8%, #7e7eff 14.8%, #7e7eff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #7e7eff;
# }
# #T_2a090_row2_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 22.5%, #c0c0ff 22.5%, #c0c0ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #c0c0ff;
# }
# #T_2a090_row2_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fffafa 30.0%, #fffafa 30.5%, transparent 30.5%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #fffafa;
# }
# #T_2a090_row3_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 2.1%, #1010ff 2.1%, #1010ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #1010ff;
# }
# #T_2a090_row3_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 27.4%, #e8e8ff 27.4%, #e8e8ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e8e8ff;
# }
# #T_2a090_row3_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 15.0%, #8080ff 15.0%, #8080ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #8080ff;
# }
# #T_2a090_row3_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 21.2%, #b4b4ff 21.2%, #b4b4ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #b4b4ff;
# }
# #T_2a090_row4_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 23.5%, #c8c8ff 23.5%, #c8c8ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #c8c8ff;
# }
# #T_2a090_row4_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 26.2%, #dedeff 26.2%, #dedeff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #dedeff;
# }
# #T_2a090_row4_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ffd4d4 30.0%, #ffd4d4 34.9%, transparent 34.9%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ffd4d4;
# }
# #T_2a090_row5_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 28.5%, #f2f2ff 28.5%, #f2f2ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #f2f2ff;
# }
# #T_2a090_row5_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ff7474 30.0%, #ff7474 46.4%, transparent 46.4%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ff7474;
# }
# #T_2a090_row5_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 22.0%, #babaff 22.0%, #babaff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #babaff;
# }
# #T_2a090_row5_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ffdcdc 30.0%, #ffdcdc 34.2%, transparent 34.2%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ffdcdc;
# }
# #T_2a090_row6_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ffa2a2 30.0%, #ffa2a2 40.8%, transparent 40.8%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ffa2a2;
# }
# #T_2a090_row6_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fff6f6 30.0%, #fff6f6 31.1%, transparent 31.1%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #fff6f6;
# }
# #T_2a090_row6_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 21.1%, #b2b2ff 21.1%, #b2b2ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #b2b2ff;
# }
# #T_2a090_row6_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 18.9%, #a0a0ff 18.9%, #a0a0ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #a0a0ff;
# }
# #T_2a090_row7_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 24.5%, #d0d0ff 24.5%, #d0d0ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #d0d0ff;
# }
# #T_2a090_row7_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ffe8e8 30.0%, #ffe8e8 32.6%, transparent 32.6%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ffe8e8;
# }
# #T_2a090_row7_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 17.9%, #9898ff 17.9%, #9898ff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #9898ff;
# }
# #T_2a090_row7_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 27.5%, #eaeaff 27.5%, #eaeaff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #eaeaff;
# }
# #T_2a090_row8_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 28.1%, #eeeeff 28.1%, #eeeeff 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #eeeeff;
# }
# #T_2a090_row8_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ffc8c8 30.0%, #ffc8c8 36.5%, transparent 36.5%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ffc8c8;
# }
# #T_2a090_row8_col2 {

# %% [markdown]
# The following example aims to give a highlight of the behavior of the new align options:

# %%
# Hide the construction of the display chart from the user
import pandas as pd
from IPython.display import HTML

# Test series
test1 = pd.Series([-100, -60, -30, -20], name="All Negative")
test2 = pd.Series([-10, -5, 0, 90], name="Both Pos and Neg")
test3 = pd.Series([10, 20, 50, 100], name="All Positive")
test4 = pd.Series([100, 103, 101, 102], name="Large Positive")


head = """
<table>
    <thead>
        <th>Align</th>
        <th>All Negative</th>
        <th>Both Neg and Pos</th>
        <th>All Positive</th>
        <th>Large Positive</th>
    </thead>
    </tbody>

"""

aligns = ["left", "right", "zero", "mid", "mean", 99]
for align in aligns:
    row = f"<tr><th>{align}</th>"
    for series in [test1, test2, test3, test4]:
        s = series.copy()
        s.name = ""
        row += "<td>{}</td>".format(
            s.to_frame()
            .style.hide(axis="index")
            .bar(align=align, color=["#d65f5f", "#5fba7d"], width=100)
            .to_html()
        )  # testn['width']
    row += "</tr>"
    head += row

head += """
</tbody>
</table>"""

# %%
HTML(head)
# Out:
# <table>
#     <thead>
#         <th>Align</th>
#         <th>All Negative</th>
#         <th>Both Neg and Pos</th>
#         <th>All Positive</th>
#         <th>Large Positive</th>
#     </thead>
#     </tbody>
#
# <tr><th>left</th><td><style type="text/css">
# #T_7027f_row0_col0 {
#   width: 10em;
# }
# #T_7027f_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7027f_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.5%, transparent 87.5%);
# }
# #T_7027f_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_7027f">
#   <thead>
#     <tr>
#       <th id="T_7027f_level0_col0" class="col_heading level0 col0" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7027f_row0_col0" class="data row0 col0" >-100</td>
#     </tr>
#     <tr>
#       <td id="T_7027f_row1_col0" class="data row1 col0" >-60</td>
#     </tr>
#     <tr>
#       <td id="T_7027f_row2_col0" class="data row2 col0" >-30</td>
#     </tr>
#     <tr>
#       <td id="T_7027f_row3_col0" class="data row3 col0" >-20</td>
#     </tr>
#   </tbody>
# </table>
# </td><td><style type="text/css">
# #T_f865e_row0_col0 {
#   width: 10em;
# }
# #T_f865e_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.0%, transparent 5.0%);
# }
# #T_f865e_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 10.0%, transparent 10.0%);
# }
# #T_f865e_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_f865e">
#   <thead>
#     <tr>
#       <th id="T_f865e_level0_col0" class="col_heading level0 col0" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f865e_row0_col0" class="data row0 col0" >-10</td>
#     </tr>
#     <tr>
#       <td id="T_f865e_row1_col0" class="data row1 col0" >-5</td>
#     </tr>
#     <tr>
#       <td id="T_f865e_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_f865e_row3_col0" class="data row3 col0" >90</td>
#     </tr>
#   </tbody>
# </table>
# </td><td><style type="text/css">
# #T_7dd1b_row0_col0 {
#   width: 10em;
# }
# #T_7dd1b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 11.1%, transparent 11.1%);
# }
# #T_7dd1b_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 44.4%, transparent 44.4%);
# }
# #T_7dd1b_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_7dd1b">
#   <thead>
#     <tr>
#       <th id="T_7dd1b_level0_col0" class="col_heading level0 col0" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7dd1b_row0_col0" class="data row0 col0" >10</td>
#     </tr>
#     <tr>
#       <td id="T_7dd1b_row1_col0" class="data row1 col0" >20</td>
#     </tr>
#     <tr>
#       <td id="T_7dd1b_row2_col0" class="data row2 col0" >50</td>
#     </tr>
#     <tr>
#       <td id="T_7dd1b_row3_col0" class="data row3 col0" >100</td>
#     </tr>
#   </tbody>
# </table>
# </td><td><style type="text/css">
# #T_d48b0_row0_col0 {
#   width: 10em;
# }
# #T_d48b0_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_d48b0_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 33.3%, transparent 33.3%);
# }
# #T_d48b0_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 66.7%, transparent 66.7%);
# }
# </style>
# <table id="T_d48b0">
#   <thead>
#     <tr>
#       <th id="T_d48b0_level0_col0" class="col_heading level0 col0" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d48b0_row0_col0" class="data row0 col0" >100</td>
#     </tr>
#     <tr>
#       <td id="T_d48b0_row1_col0" class="data row1 col0" >103</td>
#     </tr>
#     <tr>
#       <td id="T_d48b0_row2_col0" class="data row2 col0" >101</td>
#     </tr>
#     <tr>
#       <td id="T_d48b0_row3_col0" class="data row3 col0" >102</td>
#     </tr>
#   </tbody>
# </table>
# </td></tr><tr><th>right</th><td><style type="text/css">
# #T_e7940_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_e7940_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_e7940_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 87.5%, #d65f5f 87.5%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_e7940_row3_col0 {
#   width: 10em;
# }
# </style>
# <table id="T_e7940">
#   <thead>
#     <tr>
#       <th id="T_e7940_level0_col0" class="col_heading level0 col0" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e7940_row0_col0" class="data row0 col0" >-100</td>
#     </tr>
#     <tr>
#       <td id="T_e7940_row1_col0" class="data row1 col0" >-60</td>
#     </tr>
#     <tr>
#       <td id="T_e7940_row2_col0" class="data row2 col0" >-30</td>
#     </tr>
#     <tr>
#       <td id="T_e7940_row3_col0" class="data row3 col0" >-20</td>
#     </tr>
#   </tbody>
# </table>
# </td><td><style type="text/css">
# #T_f0d37_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_f0d37_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.0%, #d65f5f 5.0%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_f0d37_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 10.0%, #5fba7d 10.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_f0d37_row3_col0 {
#   width: 10em;
# }
# </style>
# <table id="T_f0d37">
#   <thead>
#     <tr>
#       <th id="T_f0d37_level0_col0" class="col_heading level0 col0" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f0d37_row0_col0" class="data row0 col0" >-10</td>
#     </tr>
#     <tr>
#       <td id="T_f0d37_row1_col0" class="data row1 col0" >-5</td>
#     </tr>
#     <tr>
#       <td id="T_f0d37_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_f0d37_row3_col0" class="data row3 col0" >90</td>
#     </tr>
#   </tbody>
# </table>
# </td><td><style type="text/css">
# #T_d5d90_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_d5d90_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 11.1%, #5fba7d 11.1%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_d5d90_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.4%, #5fba7d 44.4%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_d5d90_row3_col0 {
#   width: 10em;
# }
# </style>
# <table id="T_d5d90">
#   <thead>
#     <tr>
#       <th id="T_d5d90_level0_col0" class="col_heading level0 col0" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d5d90_row0_col0" class="data row0 col0" >10</td>
#     </tr>
#     <tr>
#       <td id="T_d5d90_row1_col0" class="data row1 col0" >20</td>
#     </tr>
#     <tr>
#       <td id="T_d5d90_row2_col0" class="data row2 col0" >50</td>
#     </tr>
#     <tr>
#       <td id="T_d5d90_row3_col0" class="data row3 col0" >100</td>
#     </tr>
#   </tbody>
# </table>
# </td><td><style type="text/css">
# #T_9ef11_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_9ef11_row1_col0 {
#   width: 10em;
# }
# #T_9ef11_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.3%, #5fba7d 33.3%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_9ef11_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 66.7%, #5fba7d 66.7%, #5fba7d 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_9ef11">
#   <thead>
#     <tr>
#       <th id="T_9ef11_level0_col0" class="col_heading level0 col0" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ef11_row0_col0" class="data row0 col0" >100</td>
#     </tr>
#     <tr>
#       <td id="T_9ef11_row1_col0" class="data row1 col0" >103</td>
#     </tr>
#     <tr>
#       <td id="T_9ef11_row2_col0" class="data row2 col0" >101</td>
#     </tr>
#     <tr>
#       <td id="T_9ef11_row3_col0" class="data row3 col0" >102</td>
#     </tr>
#   </tbody>
# </table>
# </td></tr><tr><th>zero</th><td><style type="text/css">
# #T_869b8_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%

# %% [markdown]
# ## Sharing styles

# %% [markdown]
# Say you have a lovely style built up for a DataFrame, and now you want to apply the same style to a second DataFrame. Export the style with `df1.style.export`, and import it on the second DataFrame with `df1.style.set`

# %%
style1 = (
    df2.style.map(style_negative, props="color:red;")
    .map(lambda v: "opacity: 20%;" if (v < 0.3) and (v > -0.3) else None)
    .set_table_styles([{"selector": "th", "props": "color: blue;"}])
    .hide(axis="index")
)
style1
# Out:
# <style type="text/css">
# #T_b53ac th {
#   color: blue;
# }
# #T_b53ac_row0_col0, #T_b53ac_row0_col3, #T_b53ac_row2_col3, #T_b53ac_row6_col1, #T_b53ac_row7_col1, #T_b53ac_row8_col2 {
#   opacity: 20%;
# }
# #T_b53ac_row0_col1, #T_b53ac_row3_col1, #T_b53ac_row5_col0, #T_b53ac_row7_col3, #T_b53ac_row8_col0, #T_b53ac_row9_col1 {
#   color: red;
#   opacity: 20%;
# }
# #T_b53ac_row1_col0, #T_b53ac_row2_col0, #T_b53ac_row2_col1, #T_b53ac_row2_col2, #T_b53ac_row3_col0, #T_b53ac_row3_col2, #T_b53ac_row3_col3, #T_b53ac_row4_col0, #T_b53ac_row4_col1, #T_b53ac_row5_col2, #T_b53ac_row6_col2, #T_b53ac_row6_col3, #T_b53ac_row7_col0, #T_b53ac_row7_col2, #T_b53ac_row9_col0 {
#   color: red;
# }
# </style>
# <table id="T_b53ac">
#   <thead>
#     <tr>
#       <th id="T_b53ac_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b53ac_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b53ac_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b53ac_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b53ac_row0_col0" class="data row0 col0" >0.125730</td>
#       <td id="T_b53ac_row0_col1" class="data row0 col1" >-0.132105</td>
#       <td id="T_b53ac_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_b53ac_row0_col3" class="data row0 col3" >0.104900</td>
#     </tr>
#     <tr>
#       <td id="T_b53ac_row1_col0" class="data row1 col0" >-0.535669</td>
#       <td id="T_b53ac_row1_col1" class="data row1 col1" >0.361595</td>
#       <td id="T_b53ac_row1_col2" class="data row1 col2" >1.304000</td>
#       <td id="T_b53ac_row1_col3" class="data row1 col3" >0.947081</td>
#     </tr>
#     <tr>
#       <td id="T_b53ac_row2_col0" class="data row2 col0" >-0.703735</td>
#       <td id="T_b53ac_row2_col1" class="data row2 col1" >-1.265421</td>
#       <td id="T_b53ac_row2_col2" class="data row2 col2" >-0.623274</td>
#       <td id="T_b53ac_row2_col3" class="data row2 col3" >0.041326</td>
#     </tr>
#     <tr>
#       <td id="T_b53ac_row3_col0" class="data row3 col0" >-2.325031</td>
#       <td id="T_b53ac_row3_col1" class="data row3 col1" >-0.218792</td>
#       <td id="T_b53ac_row3_col2" class="data row3 col2" >-1.245911</td>
#       <td id="T_b53ac_row3_col3" class="data row3 col3" >-0.732267</td>
#     </tr>
#     <tr>
#       <td id="T_b53ac_row4_col0" class="data row4 col0" >-0.544259</td>
#       <td id="T_b53ac_row4_col1" class="data row4 col1" >-0.316300</td>
#       <td id="T_b53ac_row4_col2" class="data row4 col2" >0.411631</td>
#       <td id="T_b53ac_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_b53ac_row5_col0" class="data row5 col0" >-0.128535</td>
#       <td id="T_b53ac_row5_col1" class="data row5 col1" >1.366463</td>
#       <td id="T_b53ac_row5_col2" class="data row5 col2" >-0.665195</td>
#       <td id="T_b53ac_row5_col3" class="data row5 col3" >0.351510</td>
#     </tr>
#     <tr>
#       <td id="T_b53ac_row6_col0" class="data row6 col0" >0.903470</td>
#       <td id="T_b53ac_row6_col1" class="data row6 col1" >0.094012</td>
#       <td id="T_b53ac_row6_col2" class="data row6 col2" >-0.743499</td>
#       <td id="T_b53ac_row6_col3" class="data row6 col3" >-0.921725</td>
#     </tr>
#     <tr>
#       <td id="T_b53ac_row7_col0" class="data row7 col0" >-0.457726</td>
#       <td id="T_b53ac_row7_col1" class="data row7 col1" >0.220195</td>
#       <td id="T_b53ac_row7_col2" class="data row7 col2" >-1.009618</td>
#       <td id="T_b53ac_row7_col3" class="data row7 col3" >-0.209176</td>
#     </tr>
#     <tr>
#       <td id="T_b53ac_row8_col0" class="data row8 col0" >-0.159225</td>
#       <td id="T_b53ac_row8_col1" class="data row8 col1" >0.540846</td>
#       <td id="T_b53ac_row8_col2" class="data row8 col2" >0.214659</td>
#       <td id="T_b53ac_row8_col3" class="data row8 col3" >0.355373</td>
#     </tr>
#     <tr>
#       <td id="T_b53ac_row9_col0" class="data row9 col0" >-0.653829</td>
#       <td id="T_b53ac_row9_col1" class="data row9 col1" >-0.129614</td>
#       <td id="T_b53ac_row9_col2" class="data row9 col2" >0.783975</td>
#       <td id="T_b53ac_row9_col3" class="data row9 col3" >1.493431</td>
#     </tr>
#   </tbody>
# </table>

# %%
style2 = df3.style
style2.use(style1.export())
style2
# Out:
# <style type="text/css">
# #T_e7067 th {
#   color: blue;
# }
# #T_e7067_row0_col0, #T_e7067_row0_col2, #T_e7067_row0_col3, #T_e7067_row2_col0, #T_e7067_row2_col3, #T_e7067_row3_col1 {
#   color: red;
# }
# #T_e7067_row0_col1, #T_e7067_row3_col0 {
#   color: red;
#   opacity: 20%;
# }
# #T_e7067_row1_col2, #T_e7067_row3_col2, #T_e7067_row3_col3 {
#   opacity: 20%;
# }
# </style>
# <table id="T_e7067">
#   <thead>
#     <tr>
#       <th id="T_e7067_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_e7067_level0_col1" class="col_heading level0 col1" >c2</th>
#       <th id="T_e7067_level0_col2" class="col_heading level0 col2" >c3</th>
#       <th id="T_e7067_level0_col3" class="col_heading level0 col3" >c4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e7067_row0_col0" class="data row0 col0" >-1.736200</td>
#       <td id="T_e7067_row0_col1" class="data row0 col1" >-0.010202</td>
#       <td id="T_e7067_row0_col2" class="data row0 col2" >-0.859117</td>
#       <td id="T_e7067_row0_col3" class="data row0 col3" >-0.448975</td>
#     </tr>
#     <tr>
#       <td id="T_e7067_row1_col0" class="data row1 col0" >0.793431</td>
#       <td id="T_e7067_row1_col1" class="data row1 col1" >0.391529</td>
#       <td id="T_e7067_row1_col2" class="data row1 col2" >0.098790</td>
#       <td id="T_e7067_row1_col3" class="data row1 col3" >1.104990</td>
#     </tr>
#     <tr>
#       <td id="T_e7067_row2_col0" class="data row2 col0" >-1.380188</td>
#       <td id="T_e7067_row2_col1" class="data row2 col1" >0.552446</td>
#       <td id="T_e7067_row2_col2" class="data row2 col2" >1.346542</td>
#       <td id="T_e7067_row2_col3" class="data row2 col3" >-0.319337</td>
#     </tr>
#     <tr>
#       <td id="T_e7067_row3_col0" class="data row3 col0" >-0.100498</td>
#       <td id="T_e7067_row3_col1" class="data row3 col1" >-1.365924</td>
#       <td id="T_e7067_row3_col2" class="data row3 col2" >0.054814</td>
#       <td id="T_e7067_row3_col3" class="data row3 col3" >0.012334</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Notice that you're able to share the styles even though they're data aware. The styles are re-evaluated on the new DataFrame they've been `use`d upon.

# %% [markdown]
# ## Limitations
#
# - DataFrame only (use `Series.to_frame().style`)
# - The index and columns do not need to be unique, but certain styling functions can only work with unique indexes.
# - No large repr, and construction performance isn't great; although we have some [HTML optimizations](#Optimization)
# - You can only apply styles, you can't insert new HTML entities, except via subclassing.

# %% [markdown]
# ## Other Fun and Useful Stuff
#
# Here are a few interesting examples.

# %% [markdown]
# ### Widgets
#
# `Styler` interacts pretty well with widgets. If you're viewing this online instead of running the notebook yourself, you're missing out on interactively adjusting the color palette.

# %%
from ipywidgets import widgets


@widgets.interact
def f(h_neg=(0, 359, 1), h_pos=(0, 359), s=(0.0, 99.9), l_post=(0.0, 99.9)):
    return df2.style.background_gradient(
        cmap=sns.palettes.diverging_palette(
            h_neg=h_neg, h_pos=h_pos, s=s, l=l_post, as_cmap=True
        )
    )
# Out:
# interactive(children=(IntSlider(value=179, description='h_neg', max=359), IntSlider(value=179, description='h_…

# %% [markdown]
# ### Magnify

# %%
def magnify():
    return [
        {"selector": "th", "props": [("font-size", "4pt")]},
        {"selector": "td", "props": [("padding", "0em 0em")]},
        {"selector": "th:hover", "props": [("font-size", "12pt")]},
        {
            "selector": "tr:hover td:hover",
            "props": [("max-width", "200px"), ("font-size", "12pt")],
        },
    ]

# %%
cmap = sns.diverging_palette(5, 250, as_cmap=True)
bigdf = pd.DataFrame(np.random.default_rng(25).standard_normal((20, 25))).cumsum()

bigdf.style.background_gradient(cmap, axis=1).set_properties(
    **{"max-width": "80px", "font-size": "1pt"}
).set_caption("Hover to magnify").format(precision=2).set_table_styles(magnify())
# Out:
# <style type="text/css">
# #T_2b62d th {
#   font-size: 4pt;
# }
# #T_2b62d td {
#   padding: 0em 0em;
# }
# #T_2b62d th:hover {
#   font-size: 12pt;
# }
# #T_2b62d tr:hover td:hover {
#   max-width: 200px;
#   font-size: 12pt;
# }
# #T_2b62d_row0_col0, #T_2b62d_row2_col24 {
#   background-color: #d4dde9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col1 {
#   background-color: #eff0f2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col2, #T_2b62d_row0_col17, #T_2b62d_row5_col18, #T_2b62d_row6_col5, #T_2b62d_row8_col15, #T_2b62d_row12_col21, #T_2b62d_row16_col17 {
#   background-color: #ecc9d0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col3, #T_2b62d_row1_col3, #T_2b62d_row2_col17, #T_2b62d_row3_col14, #T_2b62d_row4_col14, #T_2b62d_row5_col19, #T_2b62d_row6_col19, #T_2b62d_row7_col19, #T_2b62d_row8_col5, #T_2b62d_row9_col16, #T_2b62d_row10_col3, #T_2b62d_row11_col4, #T_2b62d_row12_col4, #T_2b62d_row13_col3, #T_2b62d_row14_col4, #T_2b62d_row15_col3, #T_2b62d_row16_col3, #T_2b62d_row17_col4, #T_2b62d_row18_col5, #T_2b62d_row19_col5 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col4, #T_2b62d_row7_col1, #T_2b62d_row9_col7 {
#   background-color: #eeeff2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col5, #T_2b62d_row15_col22 {
#   background-color: #a7bedb;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col6, #T_2b62d_row9_col0 {
#   background-color: #9fb8d8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col7, #T_2b62d_row0_col19, #T_2b62d_row12_col17, #T_2b62d_row17_col20, #T_2b62d_row18_col10 {
#   background-color: #ecc8cf;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col8, #T_2b62d_row1_col6, #T_2b62d_row2_col8, #T_2b62d_row3_col0, #T_2b62d_row4_col0, #T_2b62d_row5_col0, #T_2b62d_row6_col8, #T_2b62d_row7_col8, #T_2b62d_row8_col8, #T_2b62d_row9_col8, #T_2b62d_row10_col8, #T_2b62d_row11_col11, #T_2b62d_row12_col11, #T_2b62d_row13_col8, #T_2b62d_row14_col2, #T_2b62d_row15_col2, #T_2b62d_row16_col2, #T_2b62d_row17_col2, #T_2b62d_row18_col2, #T_2b62d_row19_col2 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col9 {
#   background-color: #5a88c2;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col10, #T_2b62d_row1_col21 {
#   background-color: #f0e1e4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col11, #T_2b62d_row1_col19, #T_2b62d_row10_col24, #T_2b62d_row16_col0 {
#   background-color: #f1e7e9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col12, #T_2b62d_row2_col15, #T_2b62d_row12_col9, #T_2b62d_row18_col11 {
#   background-color: #a6bdda;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col13, #T_2b62d_row4_col4, #T_2b62d_row16_col9 {
#   background-color: #f0dee2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col14, #T_2b62d_row1_col22, #T_2b62d_row2_col11 {
#   background-color: #dee4ec;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col15, #T_2b62d_row1_col23, #T_2b62d_row9_col11 {
#   background-color: #91afd4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col16, #T_2b62d_row1_col13 {
#   background-color: #94b0d4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col18, #T_2b62d_row16_col10 {
#   background-color: #edcfd5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col20, #T_2b62d_row7_col12, #T_2b62d_row8_col1, #T_2b62d_row11_col12, #T_2b62d_row16_col12 {
#   background-color: #f1f1f2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col21, #T_2b62d_row17_col8, #T_2b62d_row18_col8 {
#   background-color: #eaecf0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col22, #T_2b62d_row4_col18, #T_2b62d_row18_col9 {
#   background-color: #eed4d9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col23, #T_2b62d_row13_col9 {
#   background-color: #b4c7df;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row0_col24, #T_2b62d_row7_col13, #T_2b62d_row13_col10, #T_2b62d_row18_col7, #T_2b62d_row19_col7 {
#   background-color: #ebedf1;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col0, #T_2b62d_row1_col4, #T_2b62d_row13_col20 {
#   background-color: #cfdae7;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col1, #T_2b62d_row12_col6, #T_2b62d_row19_col3 {
#   background-color: #e17c90;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col2, #T_2b62d_row3_col1, #T_2b62d_row10_col21 {
#   background-color: #e18093;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col5, #T_2b62d_row3_col2, #T_2b62d_row3_col24, #T_2b62d_row15_col20, #T_2b62d_row18_col22 {
#   background-color: #e2e7ee;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col7, #T_2b62d_row6_col17, #T_2b62d_row14_col0, #T_2b62d_row18_col0 {
#   background-color: #f0e4e6;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col8, #T_2b62d_row13_col11 {
#   background-color: #4b7ebd;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col9 {
#   background-color: #648fc5;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col10, #T_2b62d_row4_col24, #T_2b62d_row8_col11, #T_2b62d_row10_col10 {
#   background-color: #d5deea;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col11 {
#   background-color: #b6c9e0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col12, #T_2b62d_row5_col23, #T_2b62d_row12_col0 {
#   background-color: #ccd8e7;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col14, #T_2b62d_row3_col23, #T_2b62d_row8_col12, #T_2b62d_row14_col17, #T_2b62d_row15_col6, #T_2b62d_row19_col6 {
#   background-color: #efdade;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col15, #T_2b62d_row14_col8 {
#   background-color: #799ecc;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col16, #T_2b62d_row8_col0 {
#   background-color: #a9bfdb;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col17, #T_2b62d_row3_col10, #T_2b62d_row9_col14, #T_2b62d_row9_col18 {
#   background-color: #edd0d6;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col18, #T_2b62d_row12_col10 {
#   background-color: #d8e0eb;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col20 {
#   background-color: #82a4cf;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row1_col24, #T_2b62d_row14_col11 {
#   background-color: #5f8cc3;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row2_col0 {
#   background-color: #b5c8df;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row2_col1, #T_2b62d_row7_col21, #T_2b62d_row11_col5, #T_2b62d_row11_col19 {
#   background-color: #e0748a;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row2_col2, #T_2b62d_row15_col13 {
#   background-color: #e9b1bc;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row2_col3 {
#   background-color: #d84361;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row2_col4, #T_2b62d_row9_col17 {
#   background-color: #e7a7b4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row2_col5, #T_2b62d_row3_col18, #T_2b62d_row13_col7, #T_2b62d_row15_col0 {
#   background-color: #eed6db;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row2_col6 {
#   background-color: #4d7fbe;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row2_col7 {
#   background-color: #e38a9c;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_2b62d_row2_col9, #T_2b62d_row8_col2, #T_2b62d_row12_col22, #T_2b62d_row16_col11 {
#   background-color: #9db7d7

# %% [markdown]
# ### Sticky Headers
#
# If you display a large matrix or DataFrame in a notebook, but you want to always see the column and row headers you can use the [.set_sticky][sticky] method which manipulates the table styles CSS.
#
# [sticky]: ../reference/api/pandas.io.formats.style.Styler.set_sticky.rst

# %%
bigdf = pd.DataFrame(np.random.default_rng().standard_normal((16, 100)))
bigdf.style.set_sticky(axis="index")
# Out:
# <style type="text/css">
# #T_fd040 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_fd040 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_fd040">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd040_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_fd040_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_fd040_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_fd040_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_fd040_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_fd040_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_fd040_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_fd040_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_fd040_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_fd040_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_fd040_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_fd040_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_fd040_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_fd040_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_fd040_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_fd040_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_fd040_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_fd040_level0_col17" class="col_heading level0 col17" >17</th>
#       <th id="T_fd040_level0_col18" class="col_heading level0 col18" >18</th>
#       <th id="T_fd040_level0_col19" class="col_heading level0 col19" >19</th>
#       <th id="T_fd040_level0_col20" class="col_heading level0 col20" >20</th>
#       <th id="T_fd040_level0_col21" class="col_heading level0 col21" >21</th>
#       <th id="T_fd040_level0_col22" class="col_heading level0 col22" >22</th>
#       <th id="T_fd040_level0_col23" class="col_heading level0 col23" >23</th>
#       <th id="T_fd040_level0_col24" class="col_heading level0 col24" >24</th>
#       <th id="T_fd040_level0_col25" class="col_heading level0 col25" >25</th>
#       <th id="T_fd040_level0_col26" class="col_heading level0 col26" >26</th>
#       <th id="T_fd040_level0_col27" class="col_heading level0 col27" >27</th>
#       <th id="T_fd040_level0_col28" class="col_heading level0 col28" >28</th>
#       <th id="T_fd040_level0_col29" class="col_heading level0 col29" >29</th>
#       <th id="T_fd040_level0_col30" class="col_heading level0 col30" >30</th>
#       <th id="T_fd040_level0_col31" class="col_heading level0 col31" >31</th>
#       <th id="T_fd040_level0_col32" class="col_heading level0 col32" >32</th>
#       <th id="T_fd040_level0_col33" class="col_heading level0 col33" >33</th>
#       <th id="T_fd040_level0_col34" class="col_heading level0 col34" >34</th>
#       <th id="T_fd040_level0_col35" class="col_heading level0 col35" >35</th>
#       <th id="T_fd040_level0_col36" class="col_heading level0 col36" >36</th>
#       <th id="T_fd040_level0_col37" class="col_heading level0 col37" >37</th>
#       <th id="T_fd040_level0_col38" class="col_heading level0 col38" >38</th>
#       <th id="T_fd040_level0_col39" class="col_heading level0 col39" >39</th>
#       <th id="T_fd040_level0_col40" class="col_heading level0 col40" >40</th>
#       <th id="T_fd040_level0_col41" class="col_heading level0 col41" >41</th>
#       <th id="T_fd040_level0_col42" class="col_heading level0 col42" >42</th>
#       <th id="T_fd040_level0_col43" class="col_heading level0 col43" >43</th>
#       <th id="T_fd040_level0_col44" class="col_heading level0 col44" >44</th>
#       <th id="T_fd040_level0_col45" class="col_heading level0 col45" >45</th>
#       <th id="T_fd040_level0_col46" class="col_heading level0 col46" >46</th>
#       <th id="T_fd040_level0_col47" class="col_heading level0 col47" >47</th>
#       <th id="T_fd040_level0_col48" class="col_heading level0 col48" >48</th>
#       <th id="T_fd040_level0_col49" class="col_heading level0 col49" >49</th>
#       <th id="T_fd040_level0_col50" class="col_heading level0 col50" >50</th>
#       <th id="T_fd040_level0_col51" class="col_heading level0 col51" >51</th>
#       <th id="T_fd040_level0_col52" class="col_heading level0 col52" >52</th>
#       <th id="T_fd040_level0_col53" class="col_heading level0 col53" >53</th>
#       <th id="T_fd040_level0_col54" class="col_heading level0 col54" >54</th>
#       <th id="T_fd040_level0_col55" class="col_heading level0 col55" >55</th>
#       <th id="T_fd040_level0_col56" class="col_heading level0 col56" >56</th>
#       <th id="T_fd040_level0_col57" class="col_heading level0 col57" >57</th>
#       <th id="T_fd040_level0_col58" class="col_heading level0 col58" >58</th>
#       <th id="T_fd040_level0_col59" class="col_heading level0 col59" >59</th>
#       <th id="T_fd040_level0_col60" class="col_heading level0 col60" >60</th>
#       <th id="T_fd040_level0_col61" class="col_heading level0 col61" >61</th>
#       <th id="T_fd040_level0_col62" class="col_heading level0 col62" >62</th>
#       <th id="T_fd040_level0_col63" class="col_heading level0 col63" >63</th>
#       <th id="T_fd040_level0_col64" class="col_heading level0 col64" >64</th>
#       <th id="T_fd040_level0_col65" class="col_heading level0 col65" >65</th>
#       <th id="T_fd040_level0_col66" class="col_heading level0 col66" >66</th>
#       <th id="T_fd040_level0_col67" class="col_heading level0 col67" >67</th>
#       <th id="T_fd040_level0_col68" class="col_heading level0 col68" >68</th>
#       <th id="T_fd040_level0_col69" class="col_heading level0 col69" >69</th>
#       <th id="T_fd040_level0_col70" class="col_heading level0 col70" >70</th>
#       <th id="T_fd040_level0_col71" class="col_heading level0 col71" >71</th>
#       <th id="T_fd040_level0_col72" class="col_heading level0 col72" >72</th>
#       <th id="T_fd040_level0_col73" class="col_heading level0 col73" >73</th>
#       <th id="T_fd040_level0_col74" class="col_heading level0 col74" >74</th>
#       <th id="T_fd040_level0_col75" class="col_heading level0 col75" >75</th>
#       <th id="T_fd040_level0_col76" class="col_heading level0 col76" >76</th>
#       <th id="T_fd040_level0_col77" class="col_heading level0 col77" >77</th>
#       <th id="T_fd040_level0_col78" class="col_heading level0 col78" >78</th>
#       <th id="T_fd040_level0_col79" class="col_heading level0 col79" >79</th>
#       <th id="T_fd040_level0_col80" class="col_heading level0 col80" >80</th>
#       <th id="T_fd040_level0_col81" class="col_heading level0 col81" >81</th>
#       <th id="T_fd040_level0_col82" class="col_heading level0 col82" >82</th>
#       <th id="T_fd040_level0_col83" class="col_heading level0 col83" >83</th>
#       <th id="T_fd040_level0_col84" class="col_heading level0 col84" >84</th>
#       <th id="T_fd040_level0_col85" class="col_heading level0 col85" >85</th>
#       <th id="T_fd040_level0_col86" class="col_heading level0 col86" >86</th>
#       <th id="T_fd040_level0_col87" class="col_heading level0 col87" >87</th>
#       <th id="T_fd040_level0_col88" class="col_heading level0 col88" >88</th>
#       <th id="T_fd040_level0_col89" class="col_heading level0 col89" >89</th>
#       <th id="T_fd040_level0_col90" class="col_heading level0 col90" >90</th>
#       <th id="T_fd040_level0_col91" class="col_heading level0 col91" >91</th>
#       <th id="T_fd040_level0_col92" class="col_heading level0 col92" >92</th>
#       <th id="T_fd040_level0_col93" class="col_heading level0 col93" >93</th>
#       <th id="T_fd040_level0_col94" class="col_heading level0 col94" >94</th>
#       <th id="T_fd040_level0_col95" class="col_heading level0 col95" >95</th>
#       <th id="T_fd040_level0_col96" class="col_heading level0 col96" >96</th>
#       <th id="T_fd040_level0_col97" class="col_heading level0 col97" >97</th>
#       <th id="T_fd040_level0_c

# %% [markdown]
# It is also possible to stick MultiIndexes and even only specific levels.

# %%
bigdf.index = pd.MultiIndex.from_product([["A", "B"], [0, 1], [0, 1, 2, 3]])
bigdf.style.set_sticky(axis="index", pixel_size=18, levels=[1, 2])
# Out:
# <style type="text/css">
# #T_82c4f thead tr th:nth-child(2) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   min-width: 18px;
#   max-width: 18px;
#   z-index: 3 !important;
# }
# #T_82c4f tbody tr th.level1 {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   min-width: 18px;
#   max-width: 18px;
#   z-index: 1;
# }
# #T_82c4f thead tr th:nth-child(3) {
#   position: sticky;
#   background-color: inherit;
#   left: 18px;
#   min-width: 18px;
#   max-width: 18px;
#   z-index: 3 !important;
# }
# #T_82c4f tbody tr th.level2 {
#   position: sticky;
#   background-color: inherit;
#   left: 18px;
#   min-width: 18px;
#   max-width: 18px;
#   z-index: 1;
# }
# </style>
# <table id="T_82c4f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82c4f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_82c4f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_82c4f_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_82c4f_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_82c4f_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_82c4f_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_82c4f_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_82c4f_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_82c4f_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_82c4f_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_82c4f_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_82c4f_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_82c4f_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_82c4f_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_82c4f_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_82c4f_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_82c4f_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_82c4f_level0_col17" class="col_heading level0 col17" >17</th>
#       <th id="T_82c4f_level0_col18" class="col_heading level0 col18" >18</th>
#       <th id="T_82c4f_level0_col19" class="col_heading level0 col19" >19</th>
#       <th id="T_82c4f_level0_col20" class="col_heading level0 col20" >20</th>
#       <th id="T_82c4f_level0_col21" class="col_heading level0 col21" >21</th>
#       <th id="T_82c4f_level0_col22" class="col_heading level0 col22" >22</th>
#       <th id="T_82c4f_level0_col23" class="col_heading level0 col23" >23</th>
#       <th id="T_82c4f_level0_col24" class="col_heading level0 col24" >24</th>
#       <th id="T_82c4f_level0_col25" class="col_heading level0 col25" >25</th>
#       <th id="T_82c4f_level0_col26" class="col_heading level0 col26" >26</th>
#       <th id="T_82c4f_level0_col27" class="col_heading level0 col27" >27</th>
#       <th id="T_82c4f_level0_col28" class="col_heading level0 col28" >28</th>
#       <th id="T_82c4f_level0_col29" class="col_heading level0 col29" >29</th>
#       <th id="T_82c4f_level0_col30" class="col_heading level0 col30" >30</th>
#       <th id="T_82c4f_level0_col31" class="col_heading level0 col31" >31</th>
#       <th id="T_82c4f_level0_col32" class="col_heading level0 col32" >32</th>
#       <th id="T_82c4f_level0_col33" class="col_heading level0 col33" >33</th>
#       <th id="T_82c4f_level0_col34" class="col_heading level0 col34" >34</th>
#       <th id="T_82c4f_level0_col35" class="col_heading level0 col35" >35</th>
#       <th id="T_82c4f_level0_col36" class="col_heading level0 col36" >36</th>
#       <th id="T_82c4f_level0_col37" class="col_heading level0 col37" >37</th>
#       <th id="T_82c4f_level0_col38" class="col_heading level0 col38" >38</th>
#       <th id="T_82c4f_level0_col39" class="col_heading level0 col39" >39</th>
#       <th id="T_82c4f_level0_col40" class="col_heading level0 col40" >40</th>
#       <th id="T_82c4f_level0_col41" class="col_heading level0 col41" >41</th>
#       <th id="T_82c4f_level0_col42" class="col_heading level0 col42" >42</th>
#       <th id="T_82c4f_level0_col43" class="col_heading level0 col43" >43</th>
#       <th id="T_82c4f_level0_col44" class="col_heading level0 col44" >44</th>
#       <th id="T_82c4f_level0_col45" class="col_heading level0 col45" >45</th>
#       <th id="T_82c4f_level0_col46" class="col_heading level0 col46" >46</th>
#       <th id="T_82c4f_level0_col47" class="col_heading level0 col47" >47</th>
#       <th id="T_82c4f_level0_col48" class="col_heading level0 col48" >48</th>
#       <th id="T_82c4f_level0_col49" class="col_heading level0 col49" >49</th>
#       <th id="T_82c4f_level0_col50" class="col_heading level0 col50" >50</th>
#       <th id="T_82c4f_level0_col51" class="col_heading level0 col51" >51</th>
#       <th id="T_82c4f_level0_col52" class="col_heading level0 col52" >52</th>
#       <th id="T_82c4f_level0_col53" class="col_heading level0 col53" >53</th>
#       <th id="T_82c4f_level0_col54" class="col_heading level0 col54" >54</th>
#       <th id="T_82c4f_level0_col55" class="col_heading level0 col55" >55</th>
#       <th id="T_82c4f_level0_col56" class="col_heading level0 col56" >56</th>
#       <th id="T_82c4f_level0_col57" class="col_heading level0 col57" >57</th>
#       <th id="T_82c4f_level0_col58" class="col_heading level0 col58" >58</th>
#       <th id="T_82c4f_level0_col59" class="col_heading level0 col59" >59</th>
#       <th id="T_82c4f_level0_col60" class="col_heading level0 col60" >60</th>
#       <th id="T_82c4f_level0_col61" class="col_heading level0 col61" >61</th>
#       <th id="T_82c4f_level0_col62" class="col_heading level0 col62" >62</th>
#       <th id="T_82c4f_level0_col63" class="col_heading level0 col63" >63</th>
#       <th id="T_82c4f_level0_col64" class="col_heading level0 col64" >64</th>
#       <th id="T_82c4f_level0_col65" class="col_heading level0 col65" >65</th>
#       <th id="T_82c4f_level0_col66" class="col_heading level0 col66" >66</th>
#       <th id="T_82c4f_level0_col67" class="col_heading level0 col67" >67</th>
#       <th id="T_82c4f_level0_col68" class="col_heading level0 col68" >68</th>
#       <th id="T_82c4f_level0_col69" class="col_heading level0 col69" >69</th>
#       <th id="T_82c4f_level0_col70" class="col_heading level0 col70" >70</th>
#       <th id="T_82c4f_level0_col71" class="col_heading level0 col71" >71</th>
#       <th id="T_82c4f_level0_col72" class="col_heading level0 col72" >72</th>
#       <th id="T_82c4f_level0_col73" class="col_heading level0 col73" >73</th>
#       <th id="T_82c4f_level0_col74" class="col_heading level0 col74" >74</th>
#       <th id="T_82c4f_level0_col75" class="col_heading level0 col75" >75</th>
#       <th id="T_82c4f_level0_col76" class="col_heading level0 col76" >76</th>
#       <th id="T_82c4f_level0_col77" class="col_heading level0 col77" >77</th>
#       <th id="T_82c4f_level0_col78" class="col_heading level0 col78" >78</th>
#       <th id="T_82c4f_level0_col79" class="col_heading level0 col79" >79</th>
#       <th id="T_82c4f_level0_col80" class="col_heading level0 col80" >80</th>
#       <th id="T_82c4f_level0_col81" class="col_heading level0 col81" >81</th>
#       <th id="T_82c4f_level0_col82" class="col_heading level0 col82" >82</th>
#       <th id="T_82c4f_level0_col83" class="col_heading level0 col83" >83</th>
#       <th id="T_82c4f_level0_col84" class="col_heading level0 col84" >84</th>
#       <th id="T_82c4f_level0_col85" class="col_heading level0 col85" >85</th>
#       <th id="T_82c4f_level0_col86" class="col_heading level0 col86" >86</th>
#       <th id="T_82c4f_level0_col87" class="col_heading level0 col87" >87</th>
#       <th id="T_82c4f_level0_col88" class="col_heading level0 col88" >88</th>
#       <th id="T_82c4f_level0_col89" class="col_heading level0 col89" >89</th>
#       <th id="T_82c4f_level0_col90" class="col_heading level0 col90" >90</th>
#       <th id="T_82c4f_level0_col91" class="col_heading level0 col91" >91</th>
#       <th id="T_82c4f_level0_col92" class="

# %% [markdown]
# ### HTML Escaping
#
# Suppose you have to display HTML within HTML, that can be a bit of pain when the renderer can't distinguish. You can use the `escape` formatting option to handle this, and even use it within a formatter that contains HTML itself.
#
# Note that if you're using `Styler` on untrusted, user-provided input to serve HTML then you should escape the input to prevent security vulnerabilities. See the Jinja2 documentation for more.

# %%
df4 = pd.DataFrame([["<div></div>", '"&other"', "<span></span>"]])
df4.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_d62bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d62bb_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d62bb_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d62bb_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d62bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d62bb_row0_col0" class="data row0 col0" ><div></div></td>
#       <td id="T_d62bb_row0_col1" class="data row0 col1" >"&other"</td>
#       <td id="T_d62bb_row0_col2" class="data row0 col2" ><span></span></td>
#     </tr>
#   </tbody>
# </table>

# %%
df4.style.format(escape="html")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4d0f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d0f5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4d0f5_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4d0f5_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d0f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4d0f5_row0_col0" class="data row0 col0" >&lt;div&gt;&lt;/div&gt;</td>
#       <td id="T_4d0f5_row0_col1" class="data row0 col1" >&#34;&amp;other&#34;</td>
#       <td id="T_4d0f5_row0_col2" class="data row0 col2" >&lt;span&gt;&lt;/span&gt;</td>
#     </tr>
#   </tbody>
# </table>

# %%
df4.style.format(
    '<a href="https://pandas.pydata.org" target="_blank">{}</a>', escape="html"
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1b541">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b541_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1b541_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1b541_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b541_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b541_row0_col0" class="data row0 col0" ><a href="https://pandas.pydata.org" target="_blank">&lt;div&gt;&lt;/div&gt;</a></td>
#       <td id="T_1b541_row0_col1" class="data row0 col1" ><a href="https://pandas.pydata.org" target="_blank">&#34;&amp;other&#34;</a></td>
#       <td id="T_1b541_row0_col2" class="data row0 col2" ><a href="https://pandas.pydata.org" target="_blank">&lt;span&gt;&lt;/span&gt;</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Export to Excel
#
# Some support (*since version 0.20.0*) is available for exporting styled `DataFrames` to Excel worksheets using the `OpenPyXL` or `XlsxWriter` engines. CSS2.2 properties handled include:
#
# - `background-color`
# - `border-style` properties
# - `border-width` properties
# - `border-color` properties
# - `color`
# - `font-family`
# - `font-style`
# - `font-weight`
# - `text-align`
# - `text-decoration`
# - `vertical-align`
# - `white-space: nowrap`
#
#
# - Shorthand and side-specific border properties are supported (e.g. `border-style` and `border-left-style`) as well as the `border` shorthands for all sides (`border: 1px solid green`) or specified sides (`border-left: 1px solid green`). Using a `border` shorthand will override any border properties set before it (See [CSS Working Group](https://drafts.csswg.org/css-backgrounds/#border-shorthands) for more details)
#
#
# - Only CSS2 named colors and hex colors of the form `#rgb` or `#rrggbb` are currently supported.
# - The following pseudo CSS properties are also available to set Excel specific style properties:
#     - `number-format`
#     - `border-style` (for Excel-specific styles: "hair", "mediumDashDot", "dashDotDot", "mediumDashDotDot", "dashDot", "slantDashDot", or "mediumDashed")
#
# Table level styles, and data cell CSS-classes are not included in the export to Excel: individual cells must have their properties mapped by the `Styler.apply` and/or `Styler.map` methods.

# %%
df2.style.map(style_negative, props="color:red;").highlight_max(axis=0).to_excel(
    "styled.xlsx", engine="openpyxl"
)

# %% [markdown]
# A screenshot of the output:
#
# ![Excel spreadsheet with styled DataFrame](../_static/style-excel.png)

# %% [markdown]
# ## Export to LaTeX
#
# There is support (*since version 1.3.0*) to export `Styler` to LaTeX. The documentation for the [.to_latex][latex] method gives further detail and numerous examples.
#
# [latex]: ../reference/api/pandas.io.formats.style.Styler.to_latex.rst

# %% [markdown]
# ## More About CSS and HTML
#
# Cascading Style Sheet (CSS) language, which is designed to influence how a browser renders HTML elements, has its own peculiarities. It never reports errors: it just silently ignores them and doesn't render your objects how you intend so can sometimes be frustrating. Here is a very brief primer on how ``Styler`` creates HTML and interacts with CSS, with advice on common pitfalls to avoid.

# %% [markdown]
# ### CSS Classes and Ids
#
# The precise structure of the CSS `class` attached to each cell is as follows.
#
# - Cells with Index and Column names include `index_name` and `level<k>` where `k` is its level in a MultiIndex
# - Index label cells include
#   + `row_heading`
#   + `level<k>` where `k` is the level in a MultiIndex
#   + `row<m>` where `m` is the numeric position of the row
# - Column label cells include
#   + `col_heading`
#   + `level<k>` where `k` is the level in a MultiIndex
#   + `col<n>` where `n` is the numeric position of the column
# - Data cells include
#   + `data`
#   + `row<m>`, where `m` is the numeric position of the cell.
#   + `col<n>`, where `n` is the numeric position of the cell.
# - Blank cells include `blank`
# - Trimmed cells include `col_trim` or `row_trim`
#
# The structure of the `id` is `T_uuid_level<k>_row<m>_col<n>` where `level<k>` is used only on headings, and headings will only have either `row<m>` or `col<n>` whichever is needed. By default we've also prepended each row/column identifier with a UUID unique to each DataFrame so that the style from one doesn't collide with the styling from another within the same notebook or page. You can read more about the use of UUIDs in [Optimization](#Optimization).
#
# We can see example of the HTML by calling the [.to_html()][tohtml] method.
#
# [tohtml]: ../reference/api/pandas.io.formats.style.Styler.to_html.rst

# %%
print(
    pd.DataFrame(
        [[1, 2], [3, 4]], index=["i1", "i2"], columns=["c1", "c2"]
    ).style.to_html()
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ef09b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef09b_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_ef09b_level0_col1" class="col_heading level0 col1" >c2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef09b_level0_row0" class="row_heading level0 row0" >i1</th>
#       <td id="T_ef09b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ef09b_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ef09b_level0_row1" class="row_heading level0 row1" >i2</th>
#       <td id="T_ef09b_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_ef09b_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### CSS Hierarchies
#
# The examples have shown that when CSS styles overlap, the one that comes last in the HTML render, takes precedence. So the following yield different results:

# %%
df4 = pd.DataFrame([["text"]])
df4.style.map(lambda x: "color:green;").map(lambda x: "color:red;")
# Out:
# <style type="text/css">
# #T_1347e_row0_col0 {
#   color: green;
#   color: red;
# }
# </style>
# <table id="T_1347e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1347e_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1347e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1347e_row0_col0" class="data row0 col0" >text</td>
#     </tr>
#   </tbody>
# </table>

# %%
df4.style.map(lambda x: "color:red;").map(lambda x: "color:green;")
# Out:
# <style type="text/css">
# #T_76d02_row0_col0 {
#   color: red;
#   color: green;
# }
# </style>
# <table id="T_76d02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76d02_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76d02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76d02_row0_col0" class="data row0 col0" >text</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This is only true for CSS rules that are equivalent in hierarchy, or importance. You can read more about [CSS specificity here](https://www.w3schools.com/css/css_specificity.asp) but for our purposes it suffices to summarize the key points:
#
# A CSS importance score for each HTML element is derived by starting at zero and adding:
#
#  - 1000 for an inline style attribute
#  - 100 for each ID
#  - 10 for each attribute, class or pseudo-class
#  - 1 for each element name or pseudo-element
#
# Let's use this to describe the action of the following configurations

# %%
df4.style.set_uuid("a_").set_table_styles(
    [{"selector": "td", "props": "color:red;"}]
).map(lambda x: "color:green;")
# Out:
# <style type="text/css">
# #T_a_ td {
#   color: red;
# }
# #T_a__row0_col0 {
#   color: green;
# }
# </style>
# <table id="T_a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a__level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a__level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a__row0_col0" class="data row0 col0" >text</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This text is red because the generated selector `#T_a_ td` is worth 101 (ID plus element), whereas `#T_a_row0_col0` is only worth 100 (ID), so is considered inferior even though in the HTML it comes after the previous.

# %%
df4.style.set_uuid("b_").set_table_styles(
    [
        {"selector": "td", "props": "color:red;"},
        {"selector": ".cls-1", "props": "color:blue;"},
    ]
).map(lambda x: "color:green;").set_td_classes(pd.DataFrame([["cls-1"]]))
# Out:
# <style type="text/css">
# #T_b_ td {
#   color: red;
# }
# #T_b_ .cls-1 {
#   color: blue;
# }
# #T_b__row0_col0 {
#   color: green;
# }
# </style>
# <table id="T_b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b__level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b__level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b__row0_col0" class="data row0 col0 cls-1" >text</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# In the above case the text is blue because the selector `#T_b_ .cls-1` is worth 110 (ID plus class), which takes precedence.

# %%
df4.style.set_uuid("c_").set_table_styles(
    [
        {"selector": "td", "props": "color:red;"},
        {"selector": ".cls-1", "props": "color:blue;"},
        {"selector": "td.data", "props": "color:yellow;"},
    ]
).map(lambda x: "color:green;").set_td_classes(pd.DataFrame([["cls-1"]]))
# Out:
# <style type="text/css">
# #T_c_ td {
#   color: red;
# }
# #T_c_ .cls-1 {
#   color: blue;
# }
# #T_c_ td.data {
#   color: yellow;
# }
# #T_c__row0_col0 {
#   color: green;
# }
# </style>
# <table id="T_c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c__level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c__level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c__row0_col0" class="data row0 col0 cls-1" >text</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now we have created another table style this time the selector `T_c_ td.data` (ID plus element plus class) gets bumped up to 111.
#
# If your style fails to be applied, and its really frustrating, try the `!important` trump card.

# %%
df4.style.set_uuid("d_").set_table_styles(
    [
        {"selector": "td", "props": "color:red;"},
        {"selector": ".cls-1", "props": "color:blue;"},
        {"selector": "td.data", "props": "color:yellow;"},
    ]
).map(lambda x: "color:green !important;").set_td_classes(pd.DataFrame([["cls-1"]]))
# Out:
# <style type="text/css">
# #T_d_ td {
#   color: red;
# }
# #T_d_ .cls-1 {
#   color: blue;
# }
# #T_d_ td.data {
#   color: yellow;
# }
# #T_d__row0_col0 {
#   color: green !important;
# }
# </style>
# <table id="T_d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d__level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d__level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d__row0_col0" class="data row0 col0 cls-1" >text</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Finally got that green text after all!

# %% [markdown]
# ## Extensibility
#
# The core of pandas is, and will remain, its "high-performance, easy-to-use data structures".
# With that in mind, we hope that `DataFrame.style` accomplishes two goals
#
# - Provide an API that is pleasing to use interactively and is "good enough" for many tasks
# - Provide the foundations for dedicated libraries to build on
#
# If you build a great library on top of this, let us know and we'll [link](https://pandas.pydata.org/community/ecosystem.html) to it.
#
# ### Subclassing
#
# If the default template doesn't quite suit your needs, you can subclass Styler and extend or override the template.
# We'll show an example of extending the default template to insert a custom header before each table.

# %%
from jinja2 import Environment, ChoiceLoader, FileSystemLoader
from IPython.display import HTML
from pandas.io.formats.style import Styler

# %% [markdown]
# We'll use the following template:

# %%
with open("templates/myhtml.tpl") as f_html:
    print(f_html.read())
# Out:
# {% extends "html_table.tpl" %}
# {% block table %}
# <h1>{{ table_title|default("My Table") }}</h1>
# {{ super() }}
# {% endblock table %}

# %% [markdown]
# Now that we've created a template, we need to set up a subclass of ``Styler`` that
# knows about it.

# %%
class MyStyler(Styler):
    env = Environment(
        loader=ChoiceLoader(
            [
                FileSystemLoader("templates"),  # contains ours
                Styler.loader,  # the default
            ]
        )
    )
    template_html_table = env.get_template("myhtml.tpl")

# %% [markdown]
# Notice that we include the original loader in our environment's loader.
# That's because we extend the original template, so the Jinja environment needs
# to be able to find it.
#
# Now we can use that custom styler. It's `__init__` takes a DataFrame.

# %%
MyStyler(df3)
# Out:
# <style type="text/css">
# </style>
#
#
# <h1>My Table</h1>
#
#
# <table id="T_e09f2">
#
#
#
#
#
#   <thead>
#
#
#
#     <tr>
#
#
#
#       <th class="blank" >&nbsp;</th>
#
#
#
#       <th class="blank level0" >&nbsp;</th>
#
#
#
#       <th id="T_e09f2_level0_col0" class="col_heading level0 col0" >c1</th>
#
#
#
#       <th id="T_e09f2_level0_col1" class="col_heading level0 col1" >c2</th>
#
#
#
#       <th id="T_e09f2_level0_col2" class="col_heading level0 col2" >c3</th>
#
#
#
#       <th id="T_e09f2_level0_col3" class="col_heading level0 col3" >c4</th>
#
#
#
#     </tr>
#
#
#
#   </thead>
#
#
#   <tbody>
#
#
#
#     <tr>
#
#
#       <th id="T_e09f2_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#
#       <th id="T_e09f2_level1_row0" class="row_heading level1 row0" >r1</th>
#
#       <td id="T_e09f2_row0_col0" class="data row0 col0" >-1.736200</td>
#
#       <td id="T_e09f2_row0_col1" class="data row0 col1" >-0.010202</td>
#
#       <td id="T_e09f2_row0_col2" class="data row0 col2" >-0.859117</td>
#
#       <td id="T_e09f2_row0_col3" class="data row0 col3" >-0.448975</td>
#
#
#     </tr>
#
#
#
#     <tr>
#
#
#       <th id="T_e09f2_level1_row1" class="row_heading level1 row1" >r2</th>
#
#       <td id="T_e09f2_row1_col0" class="data row1 col0" >0.793431</td>
#
#       <td id="T_e09f2_row1_col1" class="data row1 col1" >0.391529</td>
#
#       <td id="T_e09f2_row1_col2" class="data row1 col2" >0.098790</td>
#
#       <td id="T_e09f2_row1_col3" class="data row1 col3" >1.104990</td>
#
#
#     </tr>
#
#
#
#     <tr>
#
#
#       <th id="T_e09f2_level0_row2" class="row_heading level0 row2" rowspan="2">B</th>
#
#       <th id="T_e09f2_level1_row2" class="row_heading level1 row2" >r1</th>
#
#       <td id="T_e09f2_row2_col0" class="data row2 col0" >-1.380188</td>
#
#       <td id="T_e09f2_row2_col1" class="data row2 col1" >0.552446</td>
#
#       <td id="T_e09f2_row2_col2" class="data row2 col2" >1.346542</td>
#
#       <td id="T_e09f2_row2_col3" class="data row2 col3" >-0.319337</td>
#
#
#     </tr>
#
#
#
#     <tr>
#
#
#       <th id="T_e09f2_level1_row3" class="row_heading level1 row3" >r2</th>
#
#       <td id="T_e09f2_row3_col0" class="data row3 col0" >-0.100498</td>
#
#       <td id="T_e09f2_row3_col1" class="data row3 col1" >-1.365924</td>
#
#       <td id="T_e09f2_row3_col2" class="data row3 col2" >0.054814</td>
#
#       <td id="T_e09f2_row3_col3" class="data row3 col3" >0.012334</td>
#
#
#     </tr>
#
#
#
#   </tbody>
#
# </table>

# %% [markdown]
# Our custom template accepts a `table_title` keyword. We can provide the value in the `.to_html` method.

# %%
HTML(MyStyler(df3).to_html(table_title="Extending Example"))
# Out:
# <style type="text/css">
# </style>
#
#
# <h1>Extending Example</h1>
#
#
# <table id="T_9fc9f">
#
#
#
#
#
#   <thead>
#
#
#
#     <tr>
#
#
#
#       <th class="blank" >&nbsp;</th>
#
#
#
#       <th class="blank level0" >&nbsp;</th>
#
#
#
#       <th id="T_9fc9f_level0_col0" class="col_heading level0 col0" >c1</th>
#
#
#
#       <th id="T_9fc9f_level0_col1" class="col_heading level0 col1" >c2</th>
#
#
#
#       <th id="T_9fc9f_level0_col2" class="col_heading level0 col2" >c3</th>
#
#
#
#       <th id="T_9fc9f_level0_col3" class="col_heading level0 col3" >c4</th>
#
#
#
#     </tr>
#
#
#
#   </thead>
#
#
#   <tbody>
#
#
#
#     <tr>
#
#
#       <th id="T_9fc9f_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#
#       <th id="T_9fc9f_level1_row0" class="row_heading level1 row0" >r1</th>
#
#       <td id="T_9fc9f_row0_col0" class="data row0 col0" >-1.736200</td>
#
#       <td id="T_9fc9f_row0_col1" class="data row0 col1" >-0.010202</td>
#
#       <td id="T_9fc9f_row0_col2" class="data row0 col2" >-0.859117</td>
#
#       <td id="T_9fc9f_row0_col3" class="data row0 col3" >-0.448975</td>
#
#
#     </tr>
#
#
#
#     <tr>
#
#
#       <th id="T_9fc9f_level1_row1" class="row_heading level1 row1" >r2</th>
#
#       <td id="T_9fc9f_row1_col0" class="data row1 col0" >0.793431</td>
#
#       <td id="T_9fc9f_row1_col1" class="data row1 col1" >0.391529</td>
#
#       <td id="T_9fc9f_row1_col2" class="data row1 col2" >0.098790</td>
#
#       <td id="T_9fc9f_row1_col3" class="data row1 col3" >1.104990</td>
#
#
#     </tr>
#
#
#
#     <tr>
#
#
#       <th id="T_9fc9f_level0_row2" class="row_heading level0 row2" rowspan="2">B</th>
#
#       <th id="T_9fc9f_level1_row2" class="row_heading level1 row2" >r1</th>
#
#       <td id="T_9fc9f_row2_col0" class="data row2 col0" >-1.380188</td>
#
#       <td id="T_9fc9f_row2_col1" class="data row2 col1" >0.552446</td>
#
#       <td id="T_9fc9f_row2_col2" class="data row2 col2" >1.346542</td>
#
#       <td id="T_9fc9f_row2_col3" class="data row2 col3" >-0.319337</td>
#
#
#     </tr>
#
#
#
#     <tr>
#
#
#       <th id="T_9fc9f_level1_row3" class="row_heading level1 row3" >r2</th>
#
#       <td id="T_9fc9f_row3_col0" class="data row3 col0" >-0.100498</td>
#
#       <td id="T_9fc9f_row3_col1" class="data row3 col1" >-1.365924</td>
#
#       <td id="T_9fc9f_row3_col2" class="data row3 col2" >0.054814</td>
#
#       <td id="T_9fc9f_row3_col3" class="data row3 col3" >0.012334</td>
#
#
#     </tr>
#
#
#
#   </tbody>
#
# </table>

# %% [markdown]
# For convenience, we provide the `Styler.from_custom_template` method that does the same as the custom subclass.

# %%
EasyStyler = Styler.from_custom_template("templates", "myhtml.tpl")
HTML(EasyStyler(df3).to_html(table_title="Another Title"))
# Out:
# <style type="text/css">
# </style>
#
#
# <h1>Another Title</h1>
#
#
# <table id="T_3a058">
#
#
#
#
#
#   <thead>
#
#
#
#     <tr>
#
#
#
#       <th class="blank" >&nbsp;</th>
#
#
#
#       <th class="blank level0" >&nbsp;</th>
#
#
#
#       <th id="T_3a058_level0_col0" class="col_heading level0 col0" >c1</th>
#
#
#
#       <th id="T_3a058_level0_col1" class="col_heading level0 col1" >c2</th>
#
#
#
#       <th id="T_3a058_level0_col2" class="col_heading level0 col2" >c3</th>
#
#
#
#       <th id="T_3a058_level0_col3" class="col_heading level0 col3" >c4</th>
#
#
#
#     </tr>
#
#
#
#   </thead>
#
#
#   <tbody>
#
#
#
#     <tr>
#
#
#       <th id="T_3a058_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#
#       <th id="T_3a058_level1_row0" class="row_heading level1 row0" >r1</th>
#
#       <td id="T_3a058_row0_col0" class="data row0 col0" >-1.736200</td>
#
#       <td id="T_3a058_row0_col1" class="data row0 col1" >-0.010202</td>
#
#       <td id="T_3a058_row0_col2" class="data row0 col2" >-0.859117</td>
#
#       <td id="T_3a058_row0_col3" class="data row0 col3" >-0.448975</td>
#
#
#     </tr>
#
#
#
#     <tr>
#
#
#       <th id="T_3a058_level1_row1" class="row_heading level1 row1" >r2</th>
#
#       <td id="T_3a058_row1_col0" class="data row1 col0" >0.793431</td>
#
#       <td id="T_3a058_row1_col1" class="data row1 col1" >0.391529</td>
#
#       <td id="T_3a058_row1_col2" class="data row1 col2" >0.098790</td>
#
#       <td id="T_3a058_row1_col3" class="data row1 col3" >1.104990</td>
#
#
#     </tr>
#
#
#
#     <tr>
#
#
#       <th id="T_3a058_level0_row2" class="row_heading level0 row2" rowspan="2">B</th>
#
#       <th id="T_3a058_level1_row2" class="row_heading level1 row2" >r1</th>
#
#       <td id="T_3a058_row2_col0" class="data row2 col0" >-1.380188</td>
#
#       <td id="T_3a058_row2_col1" class="data row2 col1" >0.552446</td>
#
#       <td id="T_3a058_row2_col2" class="data row2 col2" >1.346542</td>
#
#       <td id="T_3a058_row2_col3" class="data row2 col3" >-0.319337</td>
#
#
#     </tr>
#
#
#
#     <tr>
#
#
#       <th id="T_3a058_level1_row3" class="row_heading level1 row3" >r2</th>
#
#       <td id="T_3a058_row3_col0" class="data row3 col0" >-0.100498</td>
#
#       <td id="T_3a058_row3_col1" class="data row3 col1" >-1.365924</td>
#
#       <td id="T_3a058_row3_col2" class="data row3 col2" >0.054814</td>
#
#       <td id="T_3a058_row3_col3" class="data row3 col3" >0.012334</td>
#
#
#     </tr>
#
#
#
#   </tbody>
#
# </table>

# %% [markdown]
# #### Template Structure
#
# Here's the template structure for the both the style generation template and the table generation template:

# %% [markdown]
# Style template:

# %%
with open("templates/html_style_structure.html") as f_sty:
    style_structure = f_sty.read()

# %%
HTML(style_structure)
# Out:
# <!--
#      This is an HTML fragment that gets included into a notebook & rst document
#
#      Inspired by nbconvert
#
#      https://github.com/jupyter/nbconvert/blob/8ac591a0b8694147d0f34bf6392594c2811c1395/docs/source/template_structure.html
#
#
#    -->
# <style type="text/css">
#     /* Overrides of notebook CSS for static HTML export */
#     .template_block {
#         background-color: hsla(120, 60%, 70%, 0.2);
#         margin: 10px;
#         padding: 5px;
#         border: 1px solid hsla(120, 60%, 70%, 0.5);
#         border-left: 2px solid black;
#     }
#     .template_block pre {
#         background: transparent;
#         padding: 0;
#     }
#     .big_vertical_ellipsis {
#         font-size: 24pt;
#     }
# </style>
#
# <div class="template_block">before_style</div>
# <div class="template_block">style
#     <pre>&lt;style type=&quot;text/css&quot;&gt;</pre>
#     <div class="template_block">table_styles</div>
#     <div class="template_block">before_cellstyle</div>
#     <div class="template_block">cellstyle</div>
#     <pre>&lt;/style&gt;</pre>
# </div><!-- /style -->

# %% [markdown]
# Table template:

# %%
with open("templates/html_table_structure.html") as f_table_struct:
    table_structure = f_table_struct.read()

# %%
HTML(table_structure)
# Out:
# <!--
#      This is an HTML fragment that gets included into a notebook & rst document
#
#      Inspired by nbconvert
#
#      https://github.com/jupyter/nbconvert/blob/8ac591a0b8694147d0f34bf6392594c2811c1395/docs/source/template_structure.html
#
#
#    -->
# <style type="text/css">
#     /* Overrides of notebook CSS for static HTML export */
#     .template_block {
#         background-color: hsla(120, 60%, 70%, 0.2);
#         margin: 10px;
#         padding: 5px;
#         border: 1px solid hsla(120, 60%, 70%, 0.5);
#         border-left: 2px solid black;
#     }
#     .template_block pre {
#         background: transparent;
#         padding: 0;
#     }
#     .big_vertical_ellipsis {
#         font-size: 24pt;
#     }
# </style>
#
# <div class="template_block" >before_table</div>
#
# <div class="template_block" >table
#     <pre>&lt;table ...&gt;</pre>
#     <div class="template_block">caption</div>
#
#     <div class="template_block" >thead
#         <div class="template_block" >before_head_rows</div>
#         <div class="template_block">head_tr (loop over headers)</div>
#         <div class="template_block" >after_head_rows</div>
#     </div>
#
#     <div class="template_block" >tbody
#         <div class="template_block" >before_rows</div>
#         <div class="template_block">tr (loop over data rows)</div>
#         <div class="template_block" >after_rows</div>
#     </div>
#     <pre>&lt;/table&gt;</pre>
# </div><!-- /table -->
#
# <div class="template_block" >after_table</div>

# %% [markdown]
# See the template in the [GitHub repo](https://github.com/pandas-dev/pandas) for more details.

# %%
# # Hack to get the same style in the notebook as the
# # main site. This is hidden in the docs.
# from IPython.display import HTML
# with open("themes/nature_with_gtoc/static/nature.css_t") as f:
#     css = f.read()

# HTML('<style>{}</style>'.format(css))
